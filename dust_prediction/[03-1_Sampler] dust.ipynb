# %%
import pandas as pd
import numpy as np

# %%
train_dataset = np.load('./data/train_image_dust.npy')
test_dataset = np.load('./data/test_image_dust.npy')

print(train_dataset.shape)
print(test_dataset.shape)
# Out:
# (2160, 10, 20)
# (720, 10, 20)

# %% [markdown]
# # Sampler

# %%
def sampler_stamp(data, stamp, lag, step, temp=False):

    num_row = len(data)
    data_x, data_y = [], []
    for idx in range(num_row-stamp*lag-step):
        y = np.array(data[stamp*lag+idx : stamp*lag+idx+step])
        if not temp:
            x = np.transpose(data[[stamp*i+idx for i in range(lag)],:], [1,2,0])
            data_x.append(x)
            y = np.transpose(y, [1,2,0])
        data_y.append(y)
    print("Sampler Return", np.shape(data_x), np.shape(data_y))
    
    if not temp:
        return np.array(data_x), np.array(data_y)
    else:
        return np.array(data_y)

# %% [markdown]
# # Make Temporal Information

# %%
print("Train shape: ", np.shape(train_dataset), ", Test shape: ", np.shape(test_dataset))

# Setting Some Parameters 
num_train, num_test = np.shape(train_dataset)[0], np.shape(test_dataset)[0]
num_row = num_train + num_test
print('num_row: ', num_row)
# Out:
# Train shape:  (2160, 10, 20) , Test shape:  (720, 10, 20)
# num_row:  2880

# %%
### Initialize numpy array of temporal information (one-hot encoding)
datasets_1h = np.zeros([num_row, 24])
datasets_dow = np.zeros([num_row, 7])

# 더미화 하기
# 1hour, and day-of-week index are calculated below
for i in range(num_row):
    idx_1h = int(int(i)%24)
    idx_dow = int(int(i/24)%7)
    datasets_1h[i,idx_1h] = 1
    datasets_dow[i, idx_dow] = 1

# %%
def train_test_split(data, idx):
    return data[:idx], data[idx:]

# %%
# Split Train & Test Period

train_index = num_train #144 # 120 days and 144 time index
hour_1_train, hour_1_test = train_test_split(datasets_1h, train_index)
dow_train, dow_test = train_test_split(datasets_dow, train_index)

print(hour_1_train.shape, hour_1_test.shape)
print(dow_train.shape, dow_test.shape)
# Out:
# (2160, 24) (720, 24)
# (2160, 7) (720, 7)

# %% [markdown]
# # Save Final Data

# %%
def save_data_stamp(STAMP, LAG, STEP):
    # train 
    x_train, y_train = sampler_stamp(train_dataset, stamp=STAMP, lag=LAG, step=1, temp=False)    
    hour_1_train_y = sampler_stamp(hour_1_train, stamp=STAMP, lag=LAG, step=1, temp=True)
    dow_train_y = sampler_stamp(dow_train, stamp=STAMP, lag=LAG, step=1, temp=True)
    temporal_train = np.concatenate((dow_train_y, hour_1_train_y), axis=-1)
    
    np.savez(f'./data/x_train_stamp{STAMP}_lag{LAG}.npz', x_train)
    np.savez(f'./data/y_train_stamp{STAMP}_lag{LAG}.npz', y_train)
    np.savez(f'./data/temporal_train_stamp{STAMP}_lag{LAG}.npz', temporal_train)
    
    # test
    x_test, y_test = sampler_stamp(test_dataset, stamp=STAMP, lag=LAG, step=STEP, temp=False)
    hour_1_test_y = sampler_stamp(hour_1_test, stamp=STAMP, lag=LAG, step=STEP, temp=True)
    dow_test_y = sampler_stamp(dow_test, stamp=STAMP, lag=LAG, step=STEP, temp=True)
    temporal_test = np.concatenate((dow_test_y, hour_1_test_y), axis=-1)

    np.savez(f'./data/x_test_stamp{STAMP}_lag{LAG}_step{STEP}.npz', x_test)
    np.savez(f'./data/y_test_stamp{STAMP}_lag{LAG}_step{STEP}.npz', y_test)
    np.savez(f'./data/temporal_test_stamp{STAMP}_lag{LAG}_step{STEP}.npz', temporal_test)

# %%
time_unit = [1,2,3,4,6,8,12,24]
stamp_list = time_unit
step_list = [int(24/i) for i in stamp_list]
lag_list = [2*(i+1) for i in range(12)]

for i in range(len(time_unit)): # time unit에 따라
    for j in range(len(lag_list)): # lag에 따라
        save_data_stamp(STAMP=stamp_list[i], LAG=lag_list[j], STEP=step_list[i])
# Out:
# Sampler Return (2157, 10, 20, 2) (2157, 10, 20, 1)
# Sampler Return (0,) (2157, 1, 24)
# Sampler Return (0,) (2157, 1, 7)
# Sampler Return (694, 10, 20, 2) (694, 10, 20, 24)
# Sampler Return (0,) (694, 24, 24)
# Sampler Return (0,) (694, 24, 7)
# Sampler Return (2155, 10, 20, 4) (2155, 10, 20, 1)
# Sampler Return (0,) (2155, 1, 24)
# Sampler Return (0,) (2155, 1, 7)
# Sampler Return (692, 10, 20, 4) (692, 10, 20, 24)
# Sampler Return (0,) (692, 24, 24)
# Sampler Return (0,) (692, 24, 7)
# Sampler Return (2153, 10, 20, 6) (2153, 10, 20, 1)
# Sampler Return (0,) (2153, 1, 24)
# Sampler Return (0,) (2153, 1, 7)
# Sampler Return (690, 10, 20, 6) (690, 10, 20, 24)
# Sampler Return (0,) (690, 24, 24)
# Sampler Return (0,) (690, 24, 7)
# Sampler Return (2151, 10, 20, 8) (2151, 10, 20, 1)
# Sampler Return (0,) (2151, 1, 24)
# Sampler Return (0,) (2151, 1, 7)
# Sampler Return (688, 10, 20, 8) (688, 10, 20, 24)
# Sampler Return (0,) (688, 24, 24)
# Sampler Return (0,) (688, 24, 7)
# Sampler Return (2149, 10, 20, 10) (2149, 10, 20, 1)
# Sampler Return (0,) (2149, 1, 24)
# Sampler Return (0,) (2149, 1, 7)
# Sampler Return (686, 10, 20, 10) (686, 10, 20, 24)
# Sampler Return (0,) (686, 24, 24)
# Sampler Return (0,) (686, 24, 7)
# Sampler Return (2147, 10, 20, 12) (2147, 10, 20, 1)
# Sampler Return (0,) (2147, 1, 24)
# Sampler Return (0,) (2147, 1, 7)
# Sampler Return (684, 10, 20, 12) (684, 10, 20, 24)
# Sampler Return (0,) (684, 24, 24)
# Sampler Return (0,) (684, 24, 7)
# Sampler Return (2145, 10, 20, 14) (2145, 10, 20, 1)
# Sampler Return (0,) (2145, 1, 24)
# Sampler Return (0,) (2145, 1, 7)
# Sampler Return (682, 10, 20, 14) (682, 10, 20, 24)
# Sampler Return (0,) (682, 24, 24)
# Sampler Return (0,) (682, 24, 7)
# Sampler Return (2143, 10, 20, 16) (2143, 10, 20, 1)
# Sampler Return (0,) (2143, 1, 24)
# Sampler Return (0,) (2143, 1, 7)
# Sampler Return (680, 10, 20, 16) (680, 10, 20, 24)
# Sampler Return (0,) (680, 24, 24)
# Sampler Return (0,) (680, 24, 7)
# Sampler Return (2141, 10, 20, 18) (2141, 10, 20, 1)
# Sampler Return (0,) (2141, 1, 24)
# Sampler Return (0,) (2141, 1, 7)
# Sampler Return (678, 10, 20, 18) (678, 10, 20, 24)
# Sampler Return (0,) (678, 24, 24)
# Sampler Return (0,) (678, 24, 7)
# Sampler Return (2139, 10, 20, 20) (2139, 10, 20, 1)
# Sampler Return (0,) (2139, 1, 24)
# Sampler Return (0,) (2139, 1, 7)
# Sampler Return (676, 10, 20, 20) (676, 10, 20, 24)
# Sampler Return (0,) (676, 24, 24)
# Sampler Return (0,) (676, 24, 7)
# Sampler Return (2137, 10, 20, 22) (2137, 10, 20, 1)
# Sampler Return (0,) (2137, 1, 24)
# Sampler Return (0,) (2137, 1, 7)
# Sampler Return (674, 10, 20, 22) (674, 10, 20, 24)
# Sampler Return (0,) (674, 24, 24)
# Sampler Return (0,) (674, 24, 7)
# Sampler Return (2135, 10, 20, 24) (2135, 10, 20, 1)
# Sampler Return (0,) (2135, 1, 24)
# Sampler Return (0,) (2135, 1, 7)
# Sampler Return (672, 10, 20, 24) (672, 10, 20, 24)
# Sampler Return (0,) (672, 24, 24)
# Sampler Return (0,) (672, 24, 7)
# Sampler Return (2155, 10, 20, 2) (2155, 10, 20, 1)
# Sampler Return (0,) (2155, 1, 24)
# Sampler Return (0,) (2155, 1, 7)
# Sampler Return (704, 10, 20, 2) (704, 10, 20, 12)
# Sampler Return (0,) (704, 12, 24)
# Sampler Return (0,) (704, 12, 7)
# Sampler Return (2151, 10, 20, 4) (2151, 10, 20, 1)
# Sampler Return (0,) (2151, 1, 24)
# Sampler Return (0,) (2151, 1, 7)
# Sampler Return (700, 10, 20, 4) (700, 10, 20, 12)
# Sampler Return (0,) (700, 12, 24)
# Sampler Return (0,) (700, 12, 7)
# Sampler Return (2147, 10, 20, 6) (2147, 10, 20, 1)
# Sampler Return (0,) (2147, 1, 24)
# Sampler Return (0,) (2147, 1, 7)
# Sampler Return (696, 10, 20, 6) (696, 10, 20, 12)
# Sampler Return (0,) (696, 12, 24)
# Sampler Return (0,) (696, 12, 7)
# Sampler Return (2143, 10, 20, 8) (2143, 10, 20, 1)
# Sampler Return (0,) (2143, 1, 24)
# Sampler Return (0,) (2143, 1, 7)
# Sampler Return (692, 10, 20, 8) (692, 10, 20, 12)
# Sampler Return (0,) (692, 12, 24)
# Sampler Return (0,) (692, 12, 7)
# Sampler Return (2139, 10, 20, 10) (2139, 10, 20, 1)
# Sampler Return (0,) (2139, 1, 24)
# Sampler Return (0,) (2139, 1, 7)
# Sampler Return (688, 10, 20, 10) (688, 10, 20, 12)
# Sampler Return (0,) (688, 12, 24)
# Sampler Return (0,) (688, 12, 7)
# Sampler Return (2135, 10, 20, 12) (2135, 10, 20, 1)
# Sampler Return (0,) (2135, 1, 24)
# Sampler Return (0,) (2135, 1, 7)
# Sampler Return (684, 10, 20, 12) (684, 10, 20, 12)
# Sampler Return (0,) (684, 12, 24)
# Sampler Return (0,) (684, 12, 7)
# Sampler Return (2131, 10, 20, 14) (2131, 10, 20, 1)
# Sampler Return (0,) (2131, 1, 24)
# Sampler Return (0,) (2131, 1, 7)
# Sampler Return (680, 10, 20, 14) (680, 10, 20, 12)
# Sampler Return (0,) (680, 12, 24)
# Sampler Return (0,) (680, 12, 7)
# Sampler Return (2127, 10, 20, 16) (2127, 10, 20, 1)
# Sampler Return (0,) (2127, 1, 24)
# Sampler Return (0,) (2127, 1, 7)
# Sampler Return (676, 10, 20, 16) (676, 10, 20, 12)
# Sampler Return (0,) (676, 12, 24)
# Sampler Return (0,) (676, 12, 7)
# Sampler Return (2123, 10, 20, 18) (2123, 10, 20, 1)
# Sampler Return (0,) (2123, 1, 24)
# Sampler Return (0,) (2123, 1, 7)
# Sampler Return (672, 10, 20, 18) (672, 10, 20, 12)
# Sampler Return (0,) (672, 12, 24)
# Sampler Return (0,) (672, 12, 7)
# Sampler Return (2119, 10, 20, 20) (2119, 10, 20, 1)
# Sampler Return (0,) (2119, 1, 24)
# Sampler Return (0,) (2119, 1, 7)
# Sampler Return (668, 10, 20, 20) (668, 10, 20, 12)
# Sampler Return (0,) (668, 12, 24)
# Sampler Return (0,) (668, 12, 7)
# Sampler Return (2115, 10, 20, 22) (2115, 10, 20, 1)
# Sampler Return (0,) (2115, 1, 24)
# Sampler Return (0,) (2115, 1, 7)
# Sampler Return (664, 10, 20, 22) (664, 10, 20, 12)
# Sampler Return (0,) (664, 12, 24)
# Sampler Return (0,) (664, 12, 7)
# Sampler Return (2111, 10, 20, 24) (2111, 10, 20, 1)
# Sampler Return (0,) (2111, 1, 24)
# Sampler Return (0,) (2111, 1, 7)
# Sampler Return (660, 10, 20, 24) (660, 10, 20, 12)
# Sampler Return (0,) (660, 12, 24)
# Sampler Return (0,) (660, 12, 7)
# Sampler Return (2153, 10, 20, 2) (2153, 10, 20, 1)
# Sampler Return (0,) (2153, 1, 24)
# Sampler Return (0,) (2153, 1, 7)
# Sampler Return (706, 10, 20, 2) (706, 10, 20, 8)
# Sampler Return (0,) (706, 8, 24)
# Sampler Return (0,) (706, 8, 7)
# Sampler Return (2147, 10, 20, 4) (2147, 10, 20, 1)
# Sampler Return (0,) (2147, 1, 24)
# Sampler Return (0,) (2147, 1, 7)
# Sampler Return (700, 10, 20, 4) (700, 10, 20, 8)
# Sampler Return (0,) (700, 8, 24)
# Sampler Return (0,) (700, 8, 7)
# Sampler Return (2141, 10, 20, 6) (2141, 10, 20, 1)
# Sampler Return (0,) (2141, 1, 24)
# Sampler Return (0,) (2141, 1, 7)
# Sampler Return (694, 10, 20, 6) (694, 10, 20, 8)
# Sampler Return (0,) (694, 8, 24)
# Sampler Return (0,) (694, 8, 7)
# Sampler Return (2135, 10, 20, 8) (2135, 10, 20, 1)
# Sampler Return (0,) (2135, 1, 24)
# Sampler Return (0,) (2135, 1, 7)
# Sampler Return (688, 10, 20, 8) (688, 10, 20, 8)
# Sampler Return (0,) (688, 8, 24)
# Sampler Return (0,) (688, 8, 7)
# Sampler Return (2129, 10, 20, 10) (2129, 10, 20, 1)
# Sampler Return (0,) (2129, 1, 24)
# Sampler Return (0,) (2129, 1, 7)
# Sampler Return (682, 10, 20, 10) (682, 10, 20, 8)
# Sampler Return (0,) (682, 8, 24)
# Sampler Return (0,) (682, 8, 7)
# Sampler Return (2123, 10, 20, 12) (2123, 10, 20, 1)
# Sampler Return (0,) (2123, 1, 24)
# Sampler Return (0,) (2123, 1, 7)
# Sampler Return (676, 10, 20, 12) (676, 10, 20, 8)
# Sampler Return (0,) (676, 8, 24)
# Sampler Return (0,) (676, 8, 7)
# Sampler Return (2117, 10, 20, 14) (2117, 10, 20, 1)
# Sampler Return (0,) (2117, 1, 24)
# Sampler Return (0,) (2117, 1, 7)
# Sampler Return (670, 10, 20, 14) (670, 10, 20, 8)
# Sampler Return (0,) (670, 8, 24)
# Sampler Return (0,) (670, 8, 7)
# Sampler Return (2111, 10, 20, 16) (2111, 10, 20, 1)
# Sampler Return (0,) (2111, 1, 24)
# Sampler Return (0,) (2111, 1, 7)
# Sampler Return (664, 10, 20, 16) (664, 10, 20, 8)
# Sampler Return (0,) (664, 8, 24)
# Sampler Return (0,) (664, 8, 7)
# Sampler Return (2105, 10, 20, 18) (2105, 10, 20, 1)
# Sampler Return (0,) (2105, 1, 24)
# Sampler Return (0,) (2105, 1, 7)
# Sampler Return (658, 10, 20, 18) (658, 10, 20, 8)
# Sampler Return (0,) (658, 8, 24)
# Sampler Return (0,) (658, 8, 7)
# Sampler Return (2099, 10, 20, 20) (2099, 10, 20, 1)
# Sampler Return (0,) (2099, 1, 24)
# Sampler Return (0,) (2099, 1, 7)
# Sampler Return (652, 10, 20, 20) (652, 10, 20, 8)
# Sampler Return (0,) (652, 8, 24)
# Sampler Return (0,) (652, 8, 7)
# Sampler Return (2093, 10, 20, 22) (2093, 10, 20, 1)
# Sampler Return (0,) (2093, 1, 24)
# Sampler Return (0,) (2093, 1, 7)
# Sampler Return (646, 10, 20, 22) (646, 10, 20, 8)
# Sampler Return (0,) (646, 8, 24)
# Sampler Return (0,) (646, 8, 7)
# Sampler Return (2087, 10, 20, 24) (2087, 10, 20, 1)
# Sampler Return (0,) (2087, 1, 24)
# Sampler Return (0,) (2087, 1, 7)
# Sampler Return (640, 10, 20, 24) (640, 10, 20, 8)
# Sampler Return (0,) (640, 8, 24)
# Sampler Return (0,) (640, 8, 7)
# Sampler Return (2151, 10, 20, 2) (2151, 10, 20, 1)
# Sampler Return (0,) (2151, 1, 24)
# Sampler Return (0,) (2151, 1, 7)
# Sampler Return (706, 10, 20, 2) (706, 10, 20, 6)
# Sampler Return (0,) (706, 6, 24)
# Sampler Return (0,) (706, 6, 7)
# Sampler Return (2143, 10, 20, 4) (2143, 10, 20, 1)
# Sampler Return (0,) (2143, 1, 24)
# Sampler Return (0,) (2143, 1, 7)
# Sampler Return (698, 10, 20, 4) (698, 10, 20, 6)
# Sampler Return (0,) (698, 6, 24)
# Sampler Return (0,) (698, 6, 7)
# Sampler Return (2135, 10, 20, 6) (2135, 10, 20, 1)
# Sampler Return (0,) (2135, 1, 24)
# Sampler Return (0,) (2135, 1, 7)
# Sampler Return (690, 10, 20, 6) (690, 10, 20, 6)
# Sampler Return (0,) (690, 6, 24)
# Sampler Return (0,) (690, 6, 7)
# Sampler Return (2127, 10, 20, 8) (2127, 10, 20, 1)
# Sampler Return (0,) (2127, 1, 24)
# Sampler Return (0,) (2127, 1, 7)
# Sampler Return (682, 10, 20, 8) (682, 10, 20, 6)
# Sampler Return (0,) (682, 6, 24)
# Sampler Return (0,) (682, 6, 7)
# Sampler Return (2119, 10, 20, 10) (2119, 10, 20, 1)
# Sampler Return (0,) (2119, 1, 24)
# Sampler Return (0,) (2119, 1, 7)
# Sampler Return (674, 10, 20, 10) (674, 10, 20, 6)
# Sampler Return (0,) (674, 6, 24)
# Sampler Return (0,) (674, 6, 7)
# Sampler Return (2111, 10, 20, 12) (2111, 10, 20, 1)
# Sampler Return (0,) (2111, 1, 24)
# Sampler Return (0,) (2111, 1, 7)
# Sampler Return (666, 10, 20, 12) (666, 10, 20, 6)
# Sampler Return (0,) (666, 6, 24)
# Sampler Return (0,) (666, 6, 7)
# Sampler Return (2103, 10, 20, 14) (2103, 10, 20, 1)
# Sampler Return (0,) (2103, 1, 24)
# Sampler Return (0,) (2103, 1, 7)
# Sampler Return (658, 10, 20, 14) (658, 10, 20, 6)
# Sampler Return (0,) (658, 6, 24)
# Sampler Return (0,) (658, 6, 7)
# Sampler Return (2095, 10, 20, 16) (2095, 10, 20, 1)
# Sampler Return (0,) (2095, 1, 24)
# Sampler Return (0,) (2095, 1, 7)
# Sampler Return (650, 10, 20, 16) (650, 10, 20, 6)
# Sampler Return (0,) (650, 6, 24)
# Sampler Return (0,) (650, 6, 7)
# Sampler Return (2087, 10, 20, 18) (2087, 10, 20, 1)
# Sampler Return (0,) (2087, 1, 24)
# Sampler Return (0,) (2087, 1, 7)
# Sampler Return (642, 10, 20, 18) (642, 10, 20, 6)
# Sampler Return (0,) (642, 6, 24)
# Sampler Return (0,) (642, 6, 7)
# Sampler Return (2079, 10, 20, 20) (2079, 10, 20, 1)
# Sampler Return (0,) (2079, 1, 24)
# Sampler Return (0,) (2079, 1, 7)
# Sampler Return (634, 10, 20, 20) (634, 10, 20, 6)
# Sampler Return (0,) (634, 6, 24)
# Sampler Return (0,) (634, 6, 7)
# Sampler Return (2071, 10, 20, 22) (2071, 10, 20, 1)
# Sampler Return (0,) (2071, 1, 24)
# Sampler Return (0,) (2071, 1, 7)
# Sampler Return (626, 10, 20, 22) (626, 10, 20, 6)
# Sampler Return (0,) (626, 6, 24)
# Sampler Return (0,) (626, 6, 7)
# Sampler Return (2063, 10, 20, 24) (2063, 10, 20, 1)
# Sampler Return (0,) (2063, 1, 24)
# Sampler Return (0,) (2063, 1, 7)
# Sampler Return (618, 10, 20, 24) (618, 10, 20, 6)
# Sampler Return (0,) (618, 6, 24)
# Sampler Return (0,) (618, 6, 7)
# Sampler Return (2147, 10, 20, 2) (2147, 10, 20, 1)
# Sampler Return (0,) (2147, 1, 24)
# Sampler Return (0,) (2147, 1, 7)
# Sampler Return (704, 10, 20, 2) (704, 10, 20, 4)
# Sampler Return (0,) (704, 4, 24)
# Sampler Return (0,) (704, 4, 7)
# Sampler Return (2135, 10, 20, 4) (2135, 10, 20, 1)
# Sampler Return (0,) (2135, 1, 24)
# Sampler Return (0,) (2135, 1, 7)
# Sampler Return (692, 10, 20, 4) (692, 10, 20, 4)
# Sampler Return (0,) (692, 4, 24)
# Sampler Return (0,) (692, 4, 7)
# Sampler Return (2123, 10, 20, 6) (2123, 10, 20, 1)
# Sampler Return (0,) (2123, 1, 24)
# Sampler Return (0,) (2123, 1, 7)
# Sampler Return (680, 10, 20, 6) (680, 10, 20, 4)
# Sampler Return (0,) (680, 4, 24)
# Sampler Return (0,) (680, 4, 7)
# Sampler Return (2111, 10, 20, 8) (2111, 10, 20, 1)
# Sampler Return (0,) (2111, 1, 24)
# Sampler Return (0,) (2111, 1, 7)
# Sampler Return (668, 10, 20, 8) (668, 10, 20, 4)
# Sampler Return (0,) (668, 4, 24)
# Sampler Return (0,) (668, 4, 7)
# Sampler Return (2099, 10, 20, 10) (2099, 10, 20, 1)
# Sampler Return (0,) (2099, 1, 24)
# Sampler Return (0,) (2099, 1, 7)
# Sampler Return (656, 10, 20, 10) (656, 10, 20, 4)
# Sampler Return (0,) (656, 4, 24)
# Sampler Return (0,) (656, 4, 7)
# Sampler Return (2087, 10, 20, 12) (2087, 10, 20, 1)
# Sampler Return (0,) (2087, 1, 24)
# Sampler Return (0,) (2087, 1, 7)
# Sampler Return (644, 10, 20, 12) (644, 10, 20, 4)
# Sampler Return (0,) (644, 4, 24)
# Sampler Return (0,) (644, 4, 7)
# Sampler Return (2075, 10, 20, 14) (2075, 10, 20, 1)
# Sampler Return (0,) (2075, 1, 24)
# Sampler Return (0,) (2075, 1, 7)
# Sampler Return (632, 10, 20, 14) (632, 10, 20, 4)
# Sampler Return (0,) (632, 4, 24)
# Sampler Return (0,) (632, 4, 7)
# Sampler Return (2063, 10, 20, 16) (2063, 10, 20, 1)
# Sampler Return (0,) (2063, 1, 24)
# Sampler Return (0,) (2063, 1, 7)
# Sampler Return (620, 10, 20, 16) (620, 10, 20, 4)
# Sampler Return (0,) (620, 4, 24)
# Sampler Return (0,) (620, 4, 7)
# Sampler Return (2051, 10, 20, 18) (2051, 10, 20, 1)
# Sampler Return (0,) (2051, 1, 24)
# Sampler Return (0,) (2051, 1, 7)
# Sampler Return (608, 10, 20, 18) (608, 10, 20, 4)
# Sampler Return (0,) (608, 4, 24)
# Sampler Return (0,) (608, 4, 7)
# Sampler Return (2039, 10, 20, 20) (2039, 10, 20, 1)
# Sampler Return (0,) (2039, 1, 24)
# Sampler Return (0,) (2039, 1, 7)
# Sampler Return (596, 10, 20, 20) (596, 10, 20, 4)
# Sampler Return (0,) (596, 4, 24)
# Sampler Return (0,) (596, 4, 7)
# Sampler Return (2027, 10, 20, 22) (2027, 10, 20, 1)
# Sampler Return (0,) (2027, 1, 24)
# Sampler Return (0,) (2027, 1, 7)
# Sampler Return (584, 10, 20, 22) (584, 10, 20, 4)
# Sampler Return (0,) (584, 4, 24)
# Sampler Return (0,) (584, 4, 7)
# Sampler Return (2015, 10, 20, 24) (2015, 10, 20, 1)
# Sampler Return (0,) (2015, 1, 24)
# Sampler Return (0,) (2015, 1, 7)
# Sampler Return (572, 10, 20, 24) (572, 10, 20, 4)
# Sampler Return (0,) (572, 4, 24)
# Sampler Return (0,) (572, 4, 7)
# Sampler Return (2143, 10, 20, 2) (2143, 10, 20, 1)
# Sampler Return (0,) (2143, 1, 24)
# Sampler Return (0,) (2143, 1, 7)
# Sampler Return (701, 10, 20, 2) (701, 10, 20, 3)
# Sampler Return (0,) (701, 3, 24)
# Sampler Return (0,) (701, 3, 7)
# Sampler Return (2127, 10, 20, 4) (2127, 10, 20, 1)
# Sampler Return (0,) (2127, 1, 24)
# Sampler Return (0,) (2127, 1, 7)
# Sampler Return (685, 10, 20, 4) (685, 10, 20, 3)
# Sampler Return (0,) (685, 3, 24)
# Sampler Return (0,) (685, 3, 7)
# Sampler Return (2111, 10, 20, 6) (2111, 10, 20, 1)
# Sampler Return (0,) (2111, 1, 24)
# Sampler Return (0,) (2111, 1, 7)
# Sampler Return (669, 10, 20, 6) (669, 10, 20, 3)
# Sampler Return (0,) (669, 3, 24)
# Sampler Return (0,) (669, 3, 7)
# Sampler Return (2095, 10, 20, 8) (2095, 10, 20, 1)
# Sampler Return (0,) (2095, 1, 24)
# Sampler Return (0,) (2095, 1, 7)
# Sampler Return (653, 10, 20, 8) (653, 10, 20, 3)
# Sampler Return (0,) (653, 3, 24)
# Sampler Return (0,) (653, 3, 7)
# Sampler Return (2079, 10, 20, 10) (2079, 10, 20, 1)
# Sampler Return (0,) (2079, 1, 24)
# Sampler Return (0,) (2079, 1, 7)
# Sampler Return (637, 10, 20, 10) (637, 10, 20, 3)
# Sampler Return (0,) (637, 3, 24)
# Sampler Return (0,) (637, 3, 7)
# Sampler Return (2063, 10, 20, 12) (2063, 10, 20, 1)
# Sampler Return (0,) (2063, 1, 24)
# Sampler Return (0,) (2063, 1, 7)
# Sampler Return (621, 10, 20, 12) (621, 10, 20, 3)
# Sampler Return (0,) (621, 3, 24)
# Sampler Return (0,) (621, 3, 7)
# Sampler Return (2047, 10, 20, 14) (2047, 10, 20, 1)
# Sampler Return (0,) (2047, 1, 24)
# Sampler Return (0,) (2047, 1, 7)
# Sampler Return (605, 10, 20, 14) (605, 10, 20, 3)
# Sampler Return (0,) (605, 3, 24)
# Sampler Return (0,) (605, 3, 7)
# Sampler Return (2031, 10, 20, 16) (2031, 10, 20, 1)
# Sampler Return (0,) (2031, 1, 24)
# Sampler Return (0,) (2031, 1, 7)
# Sampler Return (589, 10, 20, 16) (589, 10, 20, 3)
# Sampler Return (0,) (589, 3, 24)
# Sampler Return (0,) (589, 3, 7)
# Sampler Return (2015, 10, 20, 18) (2015, 10, 20, 1)
# Sampler Return (0,) (2015, 1, 24)
# Sampler Return (0,) (2015, 1, 7)
# Sampler Return (573, 10, 20, 18) (573, 10, 20, 3)
# Sampler Return (0,) (573, 3, 24)
# Sampler Return (0,) (573, 3, 7)
# Sampler Return (1999, 10, 20, 20) (1999, 10, 20, 1)
# Sampler Return (0,) (1999, 1, 24)
# Sampler Return (0,) (1999, 1, 7)
# Sampler Return (557, 10, 20, 20) (557, 10, 20, 3)
# Sampler Return (0,) (557, 3, 24)
# Sampler Return (0,) (557, 3, 7)
# Sampler Return (1983, 10, 20, 22) (1983, 10, 20, 1)
# Sampler Return (0,) (1983, 1, 24)
# Sampler Return (0,) (1983, 1, 7)
# Sampler Return (541, 10, 20, 22) (541, 10, 20, 3)
# Sampler Return (0,) (541, 3, 24)
# Sampler Return (0,) (541, 3, 7)
# Sampler Return (1967, 10, 20, 24) (1967, 10, 20, 1)
# Sampler Return (0,) (1967, 1, 24)
# Sampler Return (0,) (1967, 1, 7)
# Sampler Return (525, 10, 20, 24) (525, 10, 20, 3)
# Sampler Return (0,) (525, 3, 24)
# Sampler Return (0,) (525, 3, 7)
# Sampler Return (2135, 10, 20, 2) (2135, 10, 20, 1)
# Sampler Return (0,) (2135, 1, 24)
# Sampler Return (0,) (2135, 1, 7)
# Sampler Return (694, 10, 20, 2) (694, 10, 20, 2)
# Sampler Return (0,) (694, 2, 24)
# Sampler Return (0,) (694, 2, 7)
# Sampler Return (2111, 10, 20, 4) (2111, 10, 20, 1)
# Sampler Return (0,) (2111, 1, 24)
# Sampler Return (0,) (2111, 1, 7)
# Sampler Return (670, 10, 20, 4) (670, 10, 20, 2)
# Sampler Return (0,) (670, 2, 24)
# Sampler Return (0,) (670, 2, 7)
# Sampler Return (2087, 10, 20, 6) (2087, 10, 20, 1)
# Sampler Return (0,) (2087, 1, 24)
# Sampler Return (0,) (2087, 1, 7)
# Sampler Return (646, 10, 20, 6) (646, 10, 20, 2)
# Sampler Return (0,) (646, 2, 24)
# Sampler Return (0,) (646, 2, 7)
# Sampler Return (2063, 10, 20, 8) (2063, 10, 20, 1)
# Sampler Return (0,) (2063, 1, 24)
# Sampler Return (0,) (2063, 1, 7)
# Sampler Return (622, 10, 20, 8) (622, 10, 20, 2)
# Sampler Return (0,) (622, 2, 24)
# Sampler Return (0,) (622, 2, 7)
# Sampler Return (2039, 10, 20, 10) (2039, 10, 20, 1)
# Sampler Return (0,) (2039, 1, 24)
# Sampler Return (0,) (2039, 1, 7)
# Sampler Return (598, 10, 20, 10) (598, 10, 20, 2)
# Sampler Return (0,) (598, 2, 24)
# Sampler Return (0,) (598, 2, 7)
# Sampler Return (2015, 10, 20, 12) (2015, 10, 20, 1)
# Sampler Return (0,) (2015, 1, 24)
# Sampler Return (0,) (2015, 1, 7)
# Sampler Return (574, 10, 20, 12) (574, 10, 20, 2)
# Sampler Return (0,) (574, 2, 24)
# Sampler Return (0,) (574, 2, 7)
# Sampler Return (1991, 10, 20, 14) (1991, 10, 20, 1)
# Sampler Return (0,) (1991, 1, 24)
# Sampler Return (0,) (1991, 1, 7)
# Sampler Return (550, 10, 20, 14) (550, 10, 20, 2)
# Sampler Return (0,) (550, 2, 24)
# Sampler Return (0,) (550, 2, 7)
# Sampler Return (1967, 10, 20, 16) (1967, 10, 20, 1)
# Sampler Return (0,) (1967, 1, 24)
# Sampler Return (0,) (1967, 1, 7)
# Sampler Return (526, 10, 20, 16) (526, 10, 20, 2)
# Sampler Return (0,) (526, 2, 24)
# Sampler Return (0,) (526, 2, 7)
# Sampler Return (1943, 10, 20, 18) (1943, 10, 20, 1)
# Sampler Return (0,) (1943, 1, 24)
# Sampler Return (0,) (1943, 1, 7)
# Sampler Return (502, 10, 20, 18) (502, 10, 20, 2)
# Sampler Return (0,) (502, 2, 24)
# Sampler Return (0,) (502, 2, 7)
# Sampler Return (1919, 10, 20, 20) (1919, 10, 20, 1)
# Sampler Return (0,) (1919, 1, 24)
# Sampler Return (0,) (1919, 1, 7)
# Sampler Return (478, 10, 20, 20) (478, 10, 20, 2)
# Sampler Return (0,) (478, 2, 24)
# Sampler Return (0,) (478, 2, 7)
# Sampler Return (1895, 10, 20, 22) (1895, 10, 20, 1)
# Sampler Return (0,) (1895, 1, 24)
# Sampler Return (0,) (1895, 1, 7)
# Sampler Return (454, 10, 20, 22) (454, 10, 20, 2)
# Sampler Return (0,) (454, 2, 24)
# Sampler Return (0,) (454, 2, 7)
# Sampler Return (1871, 10, 20, 24) (1871, 10, 20, 1)
# Sampler Return (0,) (1871, 1, 24)
# Sampler Return (0,) (1871, 1, 7)
# Sampler Return (430, 10, 20, 24) (430, 10, 20, 2)
# Sampler Return (0,) (430, 2, 24)
# Sampler Return (0,) (430, 2, 7)
# Sampler Return (2111, 10, 20, 2) (2111, 10, 20, 1)
# Sampler Return (0,) (2111, 1, 24)
# Sampler Return (0,) (2111, 1, 7)
# Sampler Return (671, 10, 20, 2) (671, 10, 20, 1)
# Sampler Return (0,) (671, 1, 24)
# Sampler Return (0,) (671, 1, 7)
# Sampler Return (2063, 10, 20, 4) (2063, 10, 20, 1)
# Sampler Return (0,) (2063, 1, 24)
# Sampler Return (0,) (2063, 1, 7)
# Sampler Return (623, 10, 20, 4) (623, 10, 20, 1)
# Sampler Return (0,) (623, 1, 24)
# Sampler Return (0,) (623, 1, 7)
# Sampler Return (2015, 10, 20, 6) (2015, 10, 20, 1)
# Sampler Return (0,) (2015, 1, 24)
# Sampler Return (0,) (2015, 1, 7)
# Sampler Return (575, 10, 20, 6) (575, 10, 20, 1)
# Sampler Return (0,) (575, 1, 24)
# Sampler Return (0,) (575, 1, 7)
# Sampler Return (1967, 10, 20, 8) (1967, 10, 20, 1)
# Sampler Return (0,) (1967, 1, 24)
# Sampler Return (0,) (1967, 1, 7)
# Sampler Return (527, 10, 20, 8) (527, 10, 20, 1)
# Sampler Return (0,) (527, 1, 24)
# Sampler Return (0,) (527, 1, 7)
# Sampler Return (1919, 10, 20, 10) (1919, 10, 20, 1)
# Sampler Return (0,) (1919, 1, 24)
# Sampler Return (0,) (1919, 1, 7)
# Sampler Return (479, 10, 20, 10) (479, 10, 20, 1)
# Sampler Return (0,) (479, 1, 24)
# Sampler Return (0,) (479, 1, 7)
# Sampler Return (1871, 10, 20, 12) (1871, 10, 20, 1)
# Sampler Return (0,) (1871, 1, 24)
# Sampler Return (0,) (1871, 1, 7)
# Sampler Return (431, 10, 20, 12) (431, 10, 20, 1)
# Sampler Return (0,) (431, 1, 24)
# Sampler Return (0,) (431, 1, 7)
# Sampler Return (1823, 10, 20, 14) (1823, 10, 20, 1)
# Sampler Return (0,) (1823, 1, 24)
# Sampler Return (0,) (1823, 1, 7)
# Sampler Return (383, 10, 20, 14) (383, 10, 20, 1)
# Sampler Return (0,) (383, 1, 24)
# Sampler Return (0,) (383, 1, 7)
# Sampler Return (1775, 10, 20, 16) (1775, 10, 20, 1)
# Sampler Return (0,) (1775, 1, 24)
# Sampler Return (0,) (1775, 1, 7)
# Sampler Return (335, 10, 20, 16) (335, 10, 20, 1)
# Sampler Return (0,) (335, 1, 24)
# Sampler Return (0,) (335, 1, 7)
# Sampler Return (1727, 10, 20, 18) (1727, 10, 20, 1)
# Sampler Return (0,) (1727, 1, 24)
# Sampler Return (0,) (1727, 1, 7)
# Sampler Return (287, 10, 20, 18) (287, 10, 20, 1)
# Sampler Return (0,) (287, 1, 24)
# Sampler Return (0,) (287, 1, 7)
# Sampler Return (1679, 10, 20, 20) (1679, 10, 20, 1)
# Sampler Return (0,) (1679, 1, 24)
# Sampler Return (0,) (1679, 1, 7)
# Sampler Return (239, 10, 20, 20) (239, 10, 20, 1)
# Sampler Return (0,) (239, 1, 24)
# Sampler Return (0,) (239, 1, 7)
# Sampler Return (1631, 10, 20, 22) (1631, 10, 20, 1)
# Sampler Return (0,) (1631, 1, 24)
# Sampler Return (0,) (1631, 1, 7)
# Sampler Return (191, 10, 20, 22) (191, 10, 20, 1)
# Sampler Return (0,) (191, 1, 24)
# Sampler Return (0,) (191, 1, 7)
# Sampler Return (1583, 10, 20, 24) (1583, 10, 20, 1)
# Sampler Return (0,) (1583, 1, 24)
# Sampler Return (0,) (1583, 1, 7)
# Sampler Return (143, 10, 20, 24) (143, 10, 20, 1)
# Sampler Return (0,) (143, 1, 24)
# Sampler Return (0,) (143, 1, 7)

# %%
import pandas as pd
import numpy as np

# %%
train_dataset = np.load('./data/train_image_pop.npy')
test_dataset = np.load('./data/test_image_pop.npy')

print(train_dataset.shape)
print(test_dataset.shape)
# Out:
# (4320, 10, 20)
# (1440, 10, 20)

# %% [markdown]
# # Sampler

# %%
def sampler_stamp2(data, stamp, lag, step, temp=False):

    num_row = len(data)
    data_x, data_y = [], []
    for idx in range(num_row-stamp*lag-step):
        y = np.array(data[stamp*lag+idx+step-1])
        if not temp:
            x = np.transpose(data[[stamp*i+idx for i in range(lag)],:], [1,2,0])
            data_x.append(x)
#             y = np.transpose(y, [1,2,0])
        data_y.append(y)
    if not temp:
        data_y = np.expand_dims(data_y, axis=-1)
    else:
        data_y = np.expand_dims(data_y, axis=1)
#         data_y = np.reshape(data_y, (np.shape(data_y)[0], np.shape(data_y)[1], np.shape(data_y)[2], 1))
    print("Sampler Return", np.shape(data_x), np.shape(data_y))
    
    if not temp:
        return np.array(data_x), np.array(data_y)
    else:
        return np.array(data_y)

# %%
# sampler_stamp2(train_dataset, stamp=2, lag=8, step=24, temp=True)

# %% [markdown]
# # Make Temporal Information

# %%
print("Train shape: ", np.shape(train_dataset), ", Test shape: ", np.shape(test_dataset))

# Setting Some Parameters 
num_train, num_test = np.shape(train_dataset)[0], np.shape(test_dataset)[0]
num_row = num_train + num_test
print('num_row: ', num_row)
# Out:
# Train shape:  (4320, 10, 20) , Test shape:  (1440, 10, 20)
# num_row:  5760

# %%
### Initialize numpy array of temporal information (one-hot encoding)
datasets_min_30 = np.zeros([num_row, 48])
datasets_dow = np.zeros([num_row, 7])

# 더미화 하기
# 30 mins, and day-of-week index are calculated below
for i in range(num_row):
    idx_30 = int(int(i)%48)
    idx_dow = int(int(i/48)%7)
    datasets_min_30[i,idx_30] = 1
    datasets_dow[i, idx_dow] = 1

# %%
def train_test_split(data, idx):
    return data[:idx], data[idx:]

# %%
# Split Train & Test Period

train_index = num_train #144 # 120 days and 144 time index
min_30_train, min_30_test = train_test_split(datasets_min_30, train_index)
dow_train, dow_test = train_test_split(datasets_dow, train_index)

print(min_30_train.shape, min_30_test.shape)
print(dow_train.shape, dow_test.shape)
# Out:
# (4320, 48) (1440, 48)
# (4320, 7) (1440, 7)

# %% [markdown]
# # Save Final Data

# %%
def save_data_stamp2(STAMP, LAG, STEP):
    # train 
    x_train, y_train = sampler_stamp2(train_dataset, stamp=STAMP, lag=LAG, step=STEP, temp=False)    
    min_30_train_y = sampler_stamp2(min_30_train, stamp=STAMP, lag=LAG, step=STEP, temp=True)
    dow_train_y = sampler_stamp2(dow_train, stamp=STAMP, lag=LAG, step=STEP, temp=True)
    temporal_train = np.concatenate((dow_train_y, min_30_train_y), axis=-1)
    
    np.savez(f'./data/x_train_stamp{STAMP}_lag{LAG}_step{STEP}_v2.npz', x_train)
    np.savez(f'./data/y_train_stamp{STAMP}_lag{LAG}_step{STEP}_v2.npz', y_train)
    np.savez(f'./data/temporal_train_stamp{STAMP}_lag{LAG}_step{STEP}_v2.npz', temporal_train)
    
    # test
    x_test, y_test = sampler_stamp2(test_dataset, stamp=STAMP, lag=LAG, step=STEP, temp=False)
    min_30_test_y = sampler_stamp2(min_30_test, stamp=STAMP, lag=LAG, step=STEP, temp=True)
    dow_test_y = sampler_stamp2(dow_test, stamp=STAMP, lag=LAG, step=STEP, temp=True)
    temporal_test = np.concatenate((dow_test_y, min_30_test_y), axis=-1)

    np.savez(f'./data/x_test_stamp{STAMP}_lag{LAG}_step{STEP}_v2.npz', x_test)
    np.savez(f'./data/y_test_stamp{STAMP}_lag{LAG}_step{STEP}_v2.npz', y_test)
    np.savez(f'./data/temporal_test_stamp{STAMP}_lag{LAG}_step{STEP}_v2.npz', temporal_test)

# %% [markdown]
# ## time stamp = 1 (0.5H)

# %%
time_unit = [0.5,1,2,3,4,6,8,12,24]
stamp_list = [int(2*i) for i in time_unit]
step_list = [int(48/i) for i in stamp_list]
lag_list = [2*(i+1) for i in range(12)]

for i in range(len(time_unit)): # time unit에 따라
    for j in range(len(lag_list)): # lag에 따라
        save_data_stamp2(STAMP=stamp_list[i], LAG=lag_list[j], STEP=step_list[i])
# Out:
# Sampler Return (4270, 10, 20, 2) (4270, 10, 20, 1)
# Sampler Return (0,) (4270, 1, 48)
# Sampler Return (0,) (4270, 1, 7)
# Sampler Return (1390, 10, 20, 2) (1390, 10, 20, 1)
# Sampler Return (0,) (1390, 1, 48)
# Sampler Return (0,) (1390, 1, 7)
# Sampler Return (4268, 10, 20, 4) (4268, 10, 20, 1)
# Sampler Return (0,) (4268, 1, 48)
# Sampler Return (0,) (4268, 1, 7)
# Sampler Return (1388, 10, 20, 4) (1388, 10, 20, 1)
# Sampler Return (0,) (1388, 1, 48)
# Sampler Return (0,) (1388, 1, 7)
# Sampler Return (4266, 10, 20, 6) (4266, 10, 20, 1)
# Sampler Return (0,) (4266, 1, 48)
# Sampler Return (0,) (4266, 1, 7)
# Sampler Return (1386, 10, 20, 6) (1386, 10, 20, 1)
# Sampler Return (0,) (1386, 1, 48)
# Sampler Return (0,) (1386, 1, 7)
# Sampler Return (4264, 10, 20, 8) (4264, 10, 20, 1)
# Sampler Return (0,) (4264, 1, 48)
# Sampler Return (0,) (4264, 1, 7)
# Sampler Return (1384, 10, 20, 8) (1384, 10, 20, 1)
# Sampler Return (0,) (1384, 1, 48)
# Sampler Return (0,) (1384, 1, 7)
# Sampler Return (4262, 10, 20, 10) (4262, 10, 20, 1)
# Sampler Return (0,) (4262, 1, 48)
# Sampler Return (0,) (4262, 1, 7)
# Sampler Return (1382, 10, 20, 10) (1382, 10, 20, 1)
# Sampler Return (0,) (1382, 1, 48)
# Sampler Return (0,) (1382, 1, 7)
# Sampler Return (4260, 10, 20, 12) (4260, 10, 20, 1)
# Sampler Return (0,) (4260, 1, 48)
# Sampler Return (0,) (4260, 1, 7)
# Sampler Return (1380, 10, 20, 12) (1380, 10, 20, 1)
# Sampler Return (0,) (1380, 1, 48)
# Sampler Return (0,) (1380, 1, 7)
# Sampler Return (4258, 10, 20, 14) (4258, 10, 20, 1)
# Sampler Return (0,) (4258, 1, 48)
# Sampler Return (0,) (4258, 1, 7)
# Sampler Return (1378, 10, 20, 14) (1378, 10, 20, 1)
# Sampler Return (0,) (1378, 1, 48)
# Sampler Return (0,) (1378, 1, 7)
# Sampler Return (4256, 10, 20, 16) (4256, 10, 20, 1)
# Sampler Return (0,) (4256, 1, 48)
# Sampler Return (0,) (4256, 1, 7)
# Sampler Return (1376, 10, 20, 16) (1376, 10, 20, 1)
# Sampler Return (0,) (1376, 1, 48)
# Sampler Return (0,) (1376, 1, 7)
# Sampler Return (4254, 10, 20, 18) (4254, 10, 20, 1)
# Sampler Return (0,) (4254, 1, 48)
# Sampler Return (0,) (4254, 1, 7)
# Sampler Return (1374, 10, 20, 18) (1374, 10, 20, 1)
# Sampler Return (0,) (1374, 1, 48)
# Sampler Return (0,) (1374, 1, 7)
# Sampler Return (4252, 10, 20, 20) (4252, 10, 20, 1)
# Sampler Return (0,) (4252, 1, 48)
# Sampler Return (0,) (4252, 1, 7)
# Sampler Return (1372, 10, 20, 20) (1372, 10, 20, 1)
# Sampler Return (0,) (1372, 1, 48)
# Sampler Return (0,) (1372, 1, 7)
# Sampler Return (4250, 10, 20, 22) (4250, 10, 20, 1)
# Sampler Return (0,) (4250, 1, 48)
# Sampler Return (0,) (4250, 1, 7)
# Sampler Return (1370, 10, 20, 22) (1370, 10, 20, 1)
# Sampler Return (0,) (1370, 1, 48)
# Sampler Return (0,) (1370, 1, 7)
# Sampler Return (4248, 10, 20, 24) (4248, 10, 20, 1)
# Sampler Return (0,) (4248, 1, 48)
# Sampler Return (0,) (4248, 1, 7)
# Sampler Return (1368, 10, 20, 24) (1368, 10, 20, 1)
# Sampler Return (0,) (1368, 1, 48)
# Sampler Return (0,) (1368, 1, 7)
# Sampler Return (4292, 10, 20, 2) (4292, 10, 20, 1)
# Sampler Return (0,) (4292, 1, 48)
# Sampler Return (0,) (4292, 1, 7)
# Sampler Return (1412, 10, 20, 2) (1412, 10, 20, 1)
# Sampler Return (0,) (1412, 1, 48)
# Sampler Return (0,) (1412, 1, 7)
# Sampler Return (4288, 10, 20, 4) (4288, 10, 20, 1)
# Sampler Return (0,) (4288, 1, 48)
# Sampler Return (0,) (4288, 1, 7)
# Sampler Return (1408, 10, 20, 4) (1408, 10, 20, 1)
# Sampler Return (0,) (1408, 1, 48)
# Sampler Return (0,) (1408, 1, 7)
# Sampler Return (4284, 10, 20, 6) (4284, 10, 20, 1)
# Sampler Return (0,) (4284, 1, 48)
# Sampler Return (0,) (4284, 1, 7)
# Sampler Return (1404, 10, 20, 6) (1404, 10, 20, 1)
# Sampler Return (0,) (1404, 1, 48)
# Sampler Return (0,) (1404, 1, 7)
# Sampler Return (4280, 10, 20, 8) (4280, 10, 20, 1)
# Sampler Return (0,) (4280, 1, 48)
# Sampler Return (0,) (4280, 1, 7)
# Sampler Return (1400, 10, 20, 8) (1400, 10, 20, 1)
# Sampler Return (0,) (1400, 1, 48)
# Sampler Return (0,) (1400, 1, 7)
# Sampler Return (4276, 10, 20, 10) (4276, 10, 20, 1)
# Sampler Return (0,) (4276, 1, 48)
# Sampler Return (0,) (4276, 1, 7)
# Sampler Return (1396, 10, 20, 10) (1396, 10, 20, 1)
# Sampler Return (0,) (1396, 1, 48)
# Sampler Return (0,) (1396, 1, 7)
# Sampler Return (4272, 10, 20, 12) (4272, 10, 20, 1)
# Sampler Return (0,) (4272, 1, 48)
# Sampler Return (0,) (4272, 1, 7)
# Sampler Return (1392, 10, 20, 12) (1392, 10, 20, 1)
# Sampler Return (0,) (1392, 1, 48)
# Sampler Return (0,) (1392, 1, 7)
# Sampler Return (4268, 10, 20, 14) (4268, 10, 20, 1)
# Sampler Return (0,) (4268, 1, 48)
# Sampler Return (0,) (4268, 1, 7)
# Sampler Return (1388, 10, 20, 14) (1388, 10, 20, 1)
# Sampler Return (0,) (1388, 1, 48)
# Sampler Return (0,) (1388, 1, 7)
# Sampler Return (4264, 10, 20, 16) (4264, 10, 20, 1)
# Sampler Return (0,) (4264, 1, 48)
# Sampler Return (0,) (4264, 1, 7)
# Sampler Return (1384, 10, 20, 16) (1384, 10, 20, 1)
# Sampler Return (0,) (1384, 1, 48)
# Sampler Return (0,) (1384, 1, 7)
# Sampler Return (4260, 10, 20, 18) (4260, 10, 20, 1)
# Sampler Return (0,) (4260, 1, 48)
# Sampler Return (0,) (4260, 1, 7)
# Sampler Return (1380, 10, 20, 18) (1380, 10, 20, 1)
# Sampler Return (0,) (1380, 1, 48)
# Sampler Return (0,) (1380, 1, 7)
# Sampler Return (4256, 10, 20, 20) (4256, 10, 20, 1)
# Sampler Return (0,) (4256, 1, 48)
# Sampler Return (0,) (4256, 1, 7)
# Sampler Return (1376, 10, 20, 20) (1376, 10, 20, 1)
# Sampler Return (0,) (1376, 1, 48)
# Sampler Return (0,) (1376, 1, 7)
# Sampler Return (4252, 10, 20, 22) (4252, 10, 20, 1)
# Sampler Return (0,) (4252, 1, 48)
# Sampler Return (0,) (4252, 1, 7)
# Sampler Return (1372, 10, 20, 22) (1372, 10, 20, 1)
# Sampler Return (0,) (1372, 1, 48)
# Sampler Return (0,) (1372, 1, 7)
# Sampler Return (4248, 10, 20, 24) (4248, 10, 20, 1)
# Sampler Return (0,) (4248, 1, 48)
# Sampler Return (0,) (4248, 1, 7)
# Sampler Return (1368, 10, 20, 24) (1368, 10, 20, 1)
# Sampler Return (0,) (1368, 1, 48)
# Sampler Return (0,) (1368, 1, 7)
# Sampler Return (4300, 10, 20, 2) (4300, 10, 20, 1)
# Sampler Return (0,) (4300, 1, 48)
# Sampler Return (0,) (4300, 1, 7)
# Sampler Return (1420, 10, 20, 2) (1420, 10, 20, 1)
# Sampler Return (0,) (1420, 1, 48)
# Sampler Return (0,) (1420, 1, 7)
# Sampler Return (4292, 10, 20, 4) (4292, 10, 20, 1)
# Sampler Return (0,) (4292, 1, 48)
# Sampler Return (0,) (4292, 1, 7)
# Sampler Return (1412, 10, 20, 4) (1412, 10, 20, 1)
# Sampler Return (0,) (1412, 1, 48)
# Sampler Return (0,) (1412, 1, 7)
# Sampler Return (4284, 10, 20, 6) (4284, 10, 20, 1)
# Sampler Return (0,) (4284, 1, 48)
# Sampler Return (0,) (4284, 1, 7)
# Sampler Return (1404, 10, 20, 6) (1404, 10, 20, 1)
# Sampler Return (0,) (1404, 1, 48)
# Sampler Return (0,) (1404, 1, 7)
# Sampler Return (4276, 10, 20, 8) (4276, 10, 20, 1)
# Sampler Return (0,) (4276, 1, 48)
# Sampler Return (0,) (4276, 1, 7)
# Sampler Return (1396, 10, 20, 8) (1396, 10, 20, 1)
# Sampler Return (0,) (1396, 1, 48)
# Sampler Return (0,) (1396, 1, 7)
# Sampler Return (4268, 10, 20, 10) (4268, 10, 20, 1)
# Sampler Return (0,) (4268, 1, 48)
# Sampler Return (0,) (4268, 1, 7)
# Sampler Return (1388, 10, 20, 10) (1388, 10, 20, 1)
# Sampler Return (0,) (1388, 1, 48)
# Sampler Return (0,) (1388, 1, 7)
# Sampler Return (4260, 10, 20, 12) (4260, 10, 20, 1)
# Sampler Return (0,) (4260, 1, 48)
# Sampler Return (0,) (4260, 1, 7)
# Sampler Return (1380, 10, 20, 12) (1380, 10, 20, 1)
# Sampler Return (0,) (1380, 1, 48)
# Sampler Return (0,) (1380, 1, 7)
# Sampler Return (4252, 10, 20, 14) (4252, 10, 20, 1)
# Sampler Return (0,) (4252, 1, 48)
# Sampler Return (0,) (4252, 1, 7)
# Sampler Return (1372, 10, 20, 14) (1372, 10, 20, 1)
# Sampler Return (0,) (1372, 1, 48)
# Sampler Return (0,) (1372, 1, 7)
# Sampler Return (4244, 10, 20, 16) (4244, 10, 20, 1)
# Sampler Return (0,) (4244, 1, 48)
# Sampler Return (0,) (4244, 1, 7)
# Sampler Return (1364, 10, 20, 16) (1364, 10, 20, 1)
# Sampler Return (0,) (1364, 1, 48)
# Sampler Return (0,) (1364, 1, 7)
# Sampler Return (4236, 10, 20, 18) (4236, 10, 20, 1)
# Sampler Return (0,) (4236, 1, 48)
# Sampler Return (0,) (4236, 1, 7)
# Sampler Return (1356, 10, 20, 18) (1356, 10, 20, 1)
# Sampler Return (0,) (1356, 1, 48)
# Sampler Return (0,) (1356, 1, 7)
# Sampler Return (4228, 10, 20, 20) (4228, 10, 20, 1)
# Sampler Return (0,) (4228, 1, 48)
# Sampler Return (0,) (4228, 1, 7)
# Sampler Return (1348, 10, 20, 20) (1348, 10, 20, 1)
# Sampler Return (0,) (1348, 1, 48)
# Sampler Return (0,) (1348, 1, 7)
# Sampler Return (4220, 10, 20, 22) (4220, 10, 20, 1)
# Sampler Return (0,) (4220, 1, 48)
# Sampler Return (0,) (4220, 1, 7)
# Sampler Return (1340, 10, 20, 22) (1340, 10, 20, 1)
# Sampler Return (0,) (1340, 1, 48)
# Sampler Return (0,) (1340, 1, 7)
# Sampler Return (4212, 10, 20, 24) (4212, 10, 20, 1)
# Sampler Return (0,) (4212, 1, 48)
# Sampler Return (0,) (4212, 1, 7)
# Sampler Return (1332, 10, 20, 24) (1332, 10, 20, 1)
# Sampler Return (0,) (1332, 1, 48)
# Sampler Return (0,) (1332, 1, 7)
# Sampler Return (4300, 10, 20, 2) (4300, 10, 20, 1)
# Sampler Return (0,) (4300, 1, 48)
# Sampler Return (0,) (4300, 1, 7)
# Sampler Return (1420, 10, 20, 2) (1420, 10, 20, 1)
# Sampler Return (0,) (1420, 1, 48)
# Sampler Return (0,) (1420, 1, 7)
# Sampler Return (4288, 10, 20, 4) (4288, 10, 20, 1)
# Sampler Return (0,) (4288, 1, 48)
# Sampler Return (0,) (4288, 1, 7)
# Sampler Return (1408, 10, 20, 4) (1408, 10, 20, 1)
# Sampler Return (0,) (1408, 1, 48)
# Sampler Return (0,) (1408, 1, 7)
# Sampler Return (4276, 10, 20, 6) (4276, 10, 20, 1)
# Sampler Return (0,) (4276, 1, 48)
# Sampler Return (0,) (4276, 1, 7)
# Sampler Return (1396, 10, 20, 6) (1396, 10, 20, 1)
# Sampler Return (0,) (1396, 1, 48)
# Sampler Return (0,) (1396, 1, 7)
# Sampler Return (4264, 10, 20, 8) (4264, 10, 20, 1)
# Sampler Return (0,) (4264, 1, 48)
# Sampler Return (0,) (4264, 1, 7)
# Sampler Return (1384, 10, 20, 8) (1384, 10, 20, 1)
# Sampler Return (0,) (1384, 1, 48)
# Sampler Return (0,) (1384, 1, 7)
# Sampler Return (4252, 10, 20, 10) (4252, 10, 20, 1)
# Sampler Return (0,) (4252, 1, 48)
# Sampler Return (0,) (4252, 1, 7)
# Sampler Return (1372, 10, 20, 10) (1372, 10, 20, 1)
# Sampler Return (0,) (1372, 1, 48)
# Sampler Return (0,) (1372, 1, 7)
# Sampler Return (4240, 10, 20, 12) (4240, 10, 20, 1)
# Sampler Return (0,) (4240, 1, 48)
# Sampler Return (0,) (4240, 1, 7)
# Sampler Return (1360, 10, 20, 12) (1360, 10, 20, 1)
# Sampler Return (0,) (1360, 1, 48)
# Sampler Return (0,) (1360, 1, 7)
# Sampler Return (4228, 10, 20, 14) (4228, 10, 20, 1)
# Sampler Return (0,) (4228, 1, 48)
# Sampler Return (0,) (4228, 1, 7)
# Sampler Return (1348, 10, 20, 14) (1348, 10, 20, 1)
# Sampler Return (0,) (1348, 1, 48)
# Sampler Return (0,) (1348, 1, 7)
# Sampler Return (4216, 10, 20, 16) (4216, 10, 20, 1)
# Sampler Return (0,) (4216, 1, 48)
# Sampler Return (0,) (4216, 1, 7)
# Sampler Return (1336, 10, 20, 16) (1336, 10, 20, 1)
# Sampler Return (0,) (1336, 1, 48)
# Sampler Return (0,) (1336, 1, 7)
# Sampler Return (4204, 10, 20, 18) (4204, 10, 20, 1)
# Sampler Return (0,) (4204, 1, 48)
# Sampler Return (0,) (4204, 1, 7)
# Sampler Return (1324, 10, 20, 18) (1324, 10, 20, 1)
# Sampler Return (0,) (1324, 1, 48)
# Sampler Return (0,) (1324, 1, 7)
# Sampler Return (4192, 10, 20, 20) (4192, 10, 20, 1)
# Sampler Return (0,) (4192, 1, 48)
# Sampler Return (0,) (4192, 1, 7)
# Sampler Return (1312, 10, 20, 20) (1312, 10, 20, 1)
# Sampler Return (0,) (1312, 1, 48)
# Sampler Return (0,) (1312, 1, 7)
# Sampler Return (4180, 10, 20, 22) (4180, 10, 20, 1)
# Sampler Return (0,) (4180, 1, 48)
# Sampler Return (0,) (4180, 1, 7)
# Sampler Return (1300, 10, 20, 22) (1300, 10, 20, 1)
# Sampler Return (0,) (1300, 1, 48)
# Sampler Return (0,) (1300, 1, 7)
# Sampler Return (4168, 10, 20, 24) (4168, 10, 20, 1)
# Sampler Return (0,) (4168, 1, 48)
# Sampler Return (0,) (4168, 1, 7)
# Sampler Return (1288, 10, 20, 24) (1288, 10, 20, 1)
# Sampler Return (0,) (1288, 1, 48)
# Sampler Return (0,) (1288, 1, 7)
# Sampler Return (4298, 10, 20, 2) (4298, 10, 20, 1)
# Sampler Return (0,) (4298, 1, 48)
# Sampler Return (0,) (4298, 1, 7)
# Sampler Return (1418, 10, 20, 2) (1418, 10, 20, 1)
# Sampler Return (0,) (1418, 1, 48)
# Sampler Return (0,) (1418, 1, 7)
# Sampler Return (4282, 10, 20, 4) (4282, 10, 20, 1)
# Sampler Return (0,) (4282, 1, 48)
# Sampler Return (0,) (4282, 1, 7)
# Sampler Return (1402, 10, 20, 4) (1402, 10, 20, 1)
# Sampler Return (0,) (1402, 1, 48)
# Sampler Return (0,) (1402, 1, 7)
# Sampler Return (4266, 10, 20, 6) (4266, 10, 20, 1)
# Sampler Return (0,) (4266, 1, 48)
# Sampler Return (0,) (4266, 1, 7)
# Sampler Return (1386, 10, 20, 6) (1386, 10, 20, 1)
# Sampler Return (0,) (1386, 1, 48)
# Sampler Return (0,) (1386, 1, 7)
# Sampler Return (4250, 10, 20, 8) (4250, 10, 20, 1)
# Sampler Return (0,) (4250, 1, 48)
# Sampler Return (0,) (4250, 1, 7)
# Sampler Return (1370, 10, 20, 8) (1370, 10, 20, 1)
# Sampler Return (0,) (1370, 1, 48)
# Sampler Return (0,) (1370, 1, 7)
# Sampler Return (4234, 10, 20, 10) (4234, 10, 20, 1)
# Sampler Return (0,) (4234, 1, 48)
# Sampler Return (0,) (4234, 1, 7)
# Sampler Return (1354, 10, 20, 10) (1354, 10, 20, 1)
# Sampler Return (0,) (1354, 1, 48)
# Sampler Return (0,) (1354, 1, 7)
# Sampler Return (4218, 10, 20, 12) (4218, 10, 20, 1)
# Sampler Return (0,) (4218, 1, 48)
# Sampler Return (0,) (4218, 1, 7)
# Sampler Return (1338, 10, 20, 12) (1338, 10, 20, 1)
# Sampler Return (0,) (1338, 1, 48)
# Sampler Return (0,) (1338, 1, 7)
# Sampler Return (4202, 10, 20, 14) (4202, 10, 20, 1)
# Sampler Return (0,) (4202, 1, 48)
# Sampler Return (0,) (4202, 1, 7)
# Sampler Return (1322, 10, 20, 14) (1322, 10, 20, 1)
# Sampler Return (0,) (1322, 1, 48)
# Sampler Return (0,) (1322, 1, 7)
# Sampler Return (4186, 10, 20, 16) (4186, 10, 20, 1)
# Sampler Return (0,) (4186, 1, 48)
# Sampler Return (0,) (4186, 1, 7)
# Sampler Return (1306, 10, 20, 16) (1306, 10, 20, 1)
# Sampler Return (0,) (1306, 1, 48)
# Sampler Return (0,) (1306, 1, 7)
# Sampler Return (4170, 10, 20, 18) (4170, 10, 20, 1)
# Sampler Return (0,) (4170, 1, 48)
# Sampler Return (0,) (4170, 1, 7)
# Sampler Return (1290, 10, 20, 18) (1290, 10, 20, 1)
# Sampler Return (0,) (1290, 1, 48)
# Sampler Return (0,) (1290, 1, 7)
# Sampler Return (4154, 10, 20, 20) (4154, 10, 20, 1)
# Sampler Return (0,) (4154, 1, 48)
# Sampler Return (0,) (4154, 1, 7)
# Sampler Return (1274, 10, 20, 20) (1274, 10, 20, 1)
# Sampler Return (0,) (1274, 1, 48)
# Sampler Return (0,) (1274, 1, 7)
# Sampler Return (4138, 10, 20, 22) (4138, 10, 20, 1)
# Sampler Return (0,) (4138, 1, 48)
# Sampler Return (0,) (4138, 1, 7)
# Sampler Return (1258, 10, 20, 22) (1258, 10, 20, 1)
# Sampler Return (0,) (1258, 1, 48)
# Sampler Return (0,) (1258, 1, 7)
# Sampler Return (4122, 10, 20, 24) (4122, 10, 20, 1)
# Sampler Return (0,) (4122, 1, 48)
# Sampler Return (0,) (4122, 1, 7)
# Sampler Return (1242, 10, 20, 24) (1242, 10, 20, 1)
# Sampler Return (0,) (1242, 1, 48)
# Sampler Return (0,) (1242, 1, 7)
# Sampler Return (4292, 10, 20, 2) (4292, 10, 20, 1)
# Sampler Return (0,) (4292, 1, 48)
# Sampler Return (0,) (4292, 1, 7)
# Sampler Return (1412, 10, 20, 2) (1412, 10, 20, 1)
# Sampler Return (0,) (1412, 1, 48)
# Sampler Return (0,) (1412, 1, 7)
# Sampler Return (4268, 10, 20, 4) (4268, 10, 20, 1)
# Sampler Return (0,) (4268, 1, 48)
# Sampler Return (0,) (4268, 1, 7)
# Sampler Return (1388, 10, 20, 4) (1388, 10, 20, 1)
# Sampler Return (0,) (1388, 1, 48)
# Sampler Return (0,) (1388, 1, 7)
# Sampler Return (4244, 10, 20, 6) (4244, 10, 20, 1)
# Sampler Return (0,) (4244, 1, 48)
# Sampler Return (0,) (4244, 1, 7)
# Sampler Return (1364, 10, 20, 6) (1364, 10, 20, 1)
# Sampler Return (0,) (1364, 1, 48)
# Sampler Return (0,) (1364, 1, 7)
# Sampler Return (4220, 10, 20, 8) (4220, 10, 20, 1)
# Sampler Return (0,) (4220, 1, 48)
# Sampler Return (0,) (4220, 1, 7)
# Sampler Return (1340, 10, 20, 8) (1340, 10, 20, 1)
# Sampler Return (0,) (1340, 1, 48)
# Sampler Return (0,) (1340, 1, 7)
# Sampler Return (4196, 10, 20, 10) (4196, 10, 20, 1)
# Sampler Return (0,) (4196, 1, 48)
# Sampler Return (0,) (4196, 1, 7)
# Sampler Return (1316, 10, 20, 10) (1316, 10, 20, 1)
# Sampler Return (0,) (1316, 1, 48)
# Sampler Return (0,) (1316, 1, 7)
# Sampler Return (4172, 10, 20, 12) (4172, 10, 20, 1)
# Sampler Return (0,) (4172, 1, 48)
# Sampler Return (0,) (4172, 1, 7)
# Sampler Return (1292, 10, 20, 12) (1292, 10, 20, 1)
# Sampler Return (0,) (1292, 1, 48)
# Sampler Return (0,) (1292, 1, 7)
# Sampler Return (4148, 10, 20, 14) (4148, 10, 20, 1)
# Sampler Return (0,) (4148, 1, 48)
# Sampler Return (0,) (4148, 1, 7)
# Sampler Return (1268, 10, 20, 14) (1268, 10, 20, 1)
# Sampler Return (0,) (1268, 1, 48)
# Sampler Return (0,) (1268, 1, 7)
# Sampler Return (4124, 10, 20, 16) (4124, 10, 20, 1)
# Sampler Return (0,) (4124, 1, 48)
# Sampler Return (0,) (4124, 1, 7)
# Sampler Return (1244, 10, 20, 16) (1244, 10, 20, 1)
# Sampler Return (0,) (1244, 1, 48)
# Sampler Return (0,) (1244, 1, 7)
# Sampler Return (4100, 10, 20, 18) (4100, 10, 20, 1)
# Sampler Return (0,) (4100, 1, 48)
# Sampler Return (0,) (4100, 1, 7)
# Sampler Return (1220, 10, 20, 18) (1220, 10, 20, 1)
# Sampler Return (0,) (1220, 1, 48)
# Sampler Return (0,) (1220, 1, 7)
# Sampler Return (4076, 10, 20, 20) (4076, 10, 20, 1)
# Sampler Return (0,) (4076, 1, 48)
# Sampler Return (0,) (4076, 1, 7)
# Sampler Return (1196, 10, 20, 20) (1196, 10, 20, 1)
# Sampler Return (0,) (1196, 1, 48)
# Sampler Return (0,) (1196, 1, 7)
# Sampler Return (4052, 10, 20, 22) (4052, 10, 20, 1)
# Sampler Return (0,) (4052, 1, 48)
# Sampler Return (0,) (4052, 1, 7)
# Sampler Return (1172, 10, 20, 22) (1172, 10, 20, 1)
# Sampler Return (0,) (1172, 1, 48)
# Sampler Return (0,) (1172, 1, 7)
# Sampler Return (4028, 10, 20, 24) (4028, 10, 20, 1)
# Sampler Return (0,) (4028, 1, 48)
# Sampler Return (0,) (4028, 1, 7)
# Sampler Return (1148, 10, 20, 24) (1148, 10, 20, 1)
# Sampler Return (0,) (1148, 1, 48)
# Sampler Return (0,) (1148, 1, 7)
# Sampler Return (4285, 10, 20, 2) (4285, 10, 20, 1)
# Sampler Return (0,) (4285, 1, 48)
# Sampler Return (0,) (4285, 1, 7)
# Sampler Return (1405, 10, 20, 2) (1405, 10, 20, 1)
# Sampler Return (0,) (1405, 1, 48)
# Sampler Return (0,) (1405, 1, 7)
# Sampler Return (4253, 10, 20, 4) (4253, 10, 20, 1)
# Sampler Return (0,) (4253, 1, 48)
# Sampler Return (0,) (4253, 1, 7)
# Sampler Return (1373, 10, 20, 4) (1373, 10, 20, 1)
# Sampler Return (0,) (1373, 1, 48)
# Sampler Return (0,) (1373, 1, 7)
# Sampler Return (4221, 10, 20, 6) (4221, 10, 20, 1)
# Sampler Return (0,) (4221, 1, 48)
# Sampler Return (0,) (4221, 1, 7)
# Sampler Return (1341, 10, 20, 6) (1341, 10, 20, 1)
# Sampler Return (0,) (1341, 1, 48)
# Sampler Return (0,) (1341, 1, 7)
# Sampler Return (4189, 10, 20, 8) (4189, 10, 20, 1)
# Sampler Return (0,) (4189, 1, 48)
# Sampler Return (0,) (4189, 1, 7)
# Sampler Return (1309, 10, 20, 8) (1309, 10, 20, 1)
# Sampler Return (0,) (1309, 1, 48)
# Sampler Return (0,) (1309, 1, 7)
# Sampler Return (4157, 10, 20, 10) (4157, 10, 20, 1)
# Sampler Return (0,) (4157, 1, 48)
# Sampler Return (0,) (4157, 1, 7)
# Sampler Return (1277, 10, 20, 10) (1277, 10, 20, 1)
# Sampler Return (0,) (1277, 1, 48)
# Sampler Return (0,) (1277, 1, 7)
# Sampler Return (4125, 10, 20, 12) (4125, 10, 20, 1)
# Sampler Return (0,) (4125, 1, 48)
# Sampler Return (0,) (4125, 1, 7)
# Sampler Return (1245, 10, 20, 12) (1245, 10, 20, 1)
# Sampler Return (0,) (1245, 1, 48)
# Sampler Return (0,) (1245, 1, 7)
# Sampler Return (4093, 10, 20, 14) (4093, 10, 20, 1)
# Sampler Return (0,) (4093, 1, 48)
# Sampler Return (0,) (4093, 1, 7)
# Sampler Return (1213, 10, 20, 14) (1213, 10, 20, 1)
# Sampler Return (0,) (1213, 1, 48)
# Sampler Return (0,) (1213, 1, 7)
# Sampler Return (4061, 10, 20, 16) (4061, 10, 20, 1)
# Sampler Return (0,) (4061, 1, 48)
# Sampler Return (0,) (4061, 1, 7)
# Sampler Return (1181, 10, 20, 16) (1181, 10, 20, 1)
# Sampler Return (0,) (1181, 1, 48)
# Sampler Return (0,) (1181, 1, 7)
# Sampler Return (4029, 10, 20, 18) (4029, 10, 20, 1)
# Sampler Return (0,) (4029, 1, 48)
# Sampler Return (0,) (4029, 1, 7)
# Sampler Return (1149, 10, 20, 18) (1149, 10, 20, 1)
# Sampler Return (0,) (1149, 1, 48)
# Sampler Return (0,) (1149, 1, 7)
# Sampler Return (3997, 10, 20, 20) (3997, 10, 20, 1)
# Sampler Return (0,) (3997, 1, 48)
# Sampler Return (0,) (3997, 1, 7)
# Sampler Return (1117, 10, 20, 20) (1117, 10, 20, 1)
# Sampler Return (0,) (1117, 1, 48)
# Sampler Return (0,) (1117, 1, 7)
# Sampler Return (3965, 10, 20, 22) (3965, 10, 20, 1)
# Sampler Return (0,) (3965, 1, 48)
# Sampler Return (0,) (3965, 1, 7)
# Sampler Return (1085, 10, 20, 22) (1085, 10, 20, 1)
# Sampler Return (0,) (1085, 1, 48)
# Sampler Return (0,) (1085, 1, 7)
# Sampler Return (3933, 10, 20, 24) (3933, 10, 20, 1)
# Sampler Return (0,) (3933, 1, 48)
# Sampler Return (0,) (3933, 1, 7)
# Sampler Return (1053, 10, 20, 24) (1053, 10, 20, 1)
# Sampler Return (0,) (1053, 1, 48)
# Sampler Return (0,) (1053, 1, 7)
# Sampler Return (4270, 10, 20, 2) (4270, 10, 20, 1)
# Sampler Return (0,) (4270, 1, 48)
# Sampler Return (0,) (4270, 1, 7)
# Sampler Return (1390, 10, 20, 2) (1390, 10, 20, 1)
# Sampler Return (0,) (1390, 1, 48)
# Sampler Return (0,) (1390, 1, 7)
# Sampler Return (4222, 10, 20, 4) (4222, 10, 20, 1)
# Sampler Return (0,) (4222, 1, 48)
# Sampler Return (0,) (4222, 1, 7)
# Sampler Return (1342, 10, 20, 4) (1342, 10, 20, 1)
# Sampler Return (0,) (1342, 1, 48)
# Sampler Return (0,) (1342, 1, 7)
# Sampler Return (4174, 10, 20, 6) (4174, 10, 20, 1)
# Sampler Return (0,) (4174, 1, 48)
# Sampler Return (0,) (4174, 1, 7)
# Sampler Return (1294, 10, 20, 6) (1294, 10, 20, 1)
# Sampler Return (0,) (1294, 1, 48)
# Sampler Return (0,) (1294, 1, 7)
# Sampler Return (4126, 10, 20, 8) (4126, 10, 20, 1)
# Sampler Return (0,) (4126, 1, 48)
# Sampler Return (0,) (4126, 1, 7)
# Sampler Return (1246, 10, 20, 8) (1246, 10, 20, 1)
# Sampler Return (0,) (1246, 1, 48)
# Sampler Return (0,) (1246, 1, 7)
# Sampler Return (4078, 10, 20, 10) (4078, 10, 20, 1)
# Sampler Return (0,) (4078, 1, 48)
# Sampler Return (0,) (4078, 1, 7)
# Sampler Return (1198, 10, 20, 10) (1198, 10, 20, 1)
# Sampler Return (0,) (1198, 1, 48)
# Sampler Return (0,) (1198, 1, 7)
# Sampler Return (4030, 10, 20, 12) (4030, 10, 20, 1)
# Sampler Return (0,) (4030, 1, 48)
# Sampler Return (0,) (4030, 1, 7)
# Sampler Return (1150, 10, 20, 12) (1150, 10, 20, 1)
# Sampler Return (0,) (1150, 1, 48)
# Sampler Return (0,) (1150, 1, 7)
# Sampler Return (3982, 10, 20, 14) (3982, 10, 20, 1)
# Sampler Return (0,) (3982, 1, 48)
# Sampler Return (0,) (3982, 1, 7)
# Sampler Return (1102, 10, 20, 14) (1102, 10, 20, 1)
# Sampler Return (0,) (1102, 1, 48)
# Sampler Return (0,) (1102, 1, 7)
# Sampler Return (3934, 10, 20, 16) (3934, 10, 20, 1)
# Sampler Return (0,) (3934, 1, 48)
# Sampler Return (0,) (3934, 1, 7)
# Sampler Return (1054, 10, 20, 16) (1054, 10, 20, 1)
# Sampler Return (0,) (1054, 1, 48)
# Sampler Return (0,) (1054, 1, 7)
# Sampler Return (3886, 10, 20, 18) (3886, 10, 20, 1)
# Sampler Return (0,) (3886, 1, 48)
# Sampler Return (0,) (3886, 1, 7)
# Sampler Return (1006, 10, 20, 18) (1006, 10, 20, 1)
# Sampler Return (0,) (1006, 1, 48)
# Sampler Return (0,) (1006, 1, 7)
# Sampler Return (3838, 10, 20, 20) (3838, 10, 20, 1)
# Sampler Return (0,) (3838, 1, 48)
# Sampler Return (0,) (3838, 1, 7)
# Sampler Return (958, 10, 20, 20) (958, 10, 20, 1)
# Sampler Return (0,) (958, 1, 48)
# Sampler Return (0,) (958, 1, 7)
# Sampler Return (3790, 10, 20, 22) (3790, 10, 20, 1)
# Sampler Return (0,) (3790, 1, 48)
# Sampler Return (0,) (3790, 1, 7)
# Sampler Return (910, 10, 20, 22) (910, 10, 20, 1)
# Sampler Return (0,) (910, 1, 48)
# Sampler Return (0,) (910, 1, 7)
# Sampler Return (3742, 10, 20, 24) (3742, 10, 20, 1)
# Sampler Return (0,) (3742, 1, 48)
# Sampler Return (0,) (3742, 1, 7)
# Sampler Return (862, 10, 20, 24) (862, 10, 20, 1)
# Sampler Return (0,) (862, 1, 48)
# Sampler Return (0,) (862, 1, 7)
# Sampler Return (4223, 10, 20, 2) (4223, 10, 20, 1)
# Sampler Return (0,) (4223, 1, 48)
# Sampler Return (0,) (4223, 1, 7)
# Sampler Return (1343, 10, 20, 2) (1343, 10, 20, 1)
# Sampler Return (0,) (1343, 1, 48)
# Sampler Return (0,) (1343, 1, 7)
# Sampler Return (4127, 10, 20, 4) (4127, 10, 20, 1)
# Sampler Return (0,) (4127, 1, 48)
# Sampler Return (0,) (4127, 1, 7)
# Sampler Return (1247, 10, 20, 4) (1247, 10, 20, 1)
# Sampler Return (0,) (1247, 1, 48)
# Sampler Return (0,) (1247, 1, 7)
# Sampler Return (4031, 10, 20, 6) (4031, 10, 20, 1)
# Sampler Return (0,) (4031, 1, 48)
# Sampler Return (0,) (4031, 1, 7)
# Sampler Return (1151, 10, 20, 6) (1151, 10, 20, 1)
# Sampler Return (0,) (1151, 1, 48)
# Sampler Return (0,) (1151, 1, 7)
# Sampler Return (3935, 10, 20, 8) (3935, 10, 20, 1)
# Sampler Return (0,) (3935, 1, 48)
# Sampler Return (0,) (3935, 1, 7)
# Sampler Return (1055, 10, 20, 8) (1055, 10, 20, 1)
# Sampler Return (0,) (1055, 1, 48)
# Sampler Return (0,) (1055, 1, 7)
# Sampler Return (3839, 10, 20, 10) (3839, 10, 20, 1)
# Sampler Return (0,) (3839, 1, 48)
# Sampler Return (0,) (3839, 1, 7)
# Sampler Return (959, 10, 20, 10) (959, 10, 20, 1)
# Sampler Return (0,) (959, 1, 48)
# Sampler Return (0,) (959, 1, 7)
# Sampler Return (3743, 10, 20, 12) (3743, 10, 20, 1)
# Sampler Return (0,) (3743, 1, 48)
# Sampler Return (0,) (3743, 1, 7)
# Sampler Return (863, 10, 20, 12) (863, 10, 20, 1)
# Sampler Return (0,) (863, 1, 48)
# Sampler Return (0,) (863, 1, 7)
# Sampler Return (3647, 10, 20, 14) (3647, 10, 20, 1)
# Sampler Return (0,) (3647, 1, 48)
# Sampler Return (0,) (3647, 1, 7)
# Sampler Return (767, 10, 20, 14) (767, 10, 20, 1)
# Sampler Return (0,) (767, 1, 48)
# Sampler Return (0,) (767, 1, 7)
# Sampler Return (3551, 10, 20, 16) (3551, 10, 20, 1)
# Sampler Return (0,) (3551, 1, 48)
# Sampler Return (0,) (3551, 1, 7)
# Sampler Return (671, 10, 20, 16) (671, 10, 20, 1)
# Sampler Return (0,) (671, 1, 48)
# Sampler Return (0,) (671, 1, 7)
# Sampler Return (3455, 10, 20, 18) (3455, 10, 20, 1)
# Sampler Return (0,) (3455, 1, 48)
# Sampler Return (0,) (3455, 1, 7)
# Sampler Return (575, 10, 20, 18) (575, 10, 20, 1)
# Sampler Return (0,) (575, 1, 48)
# Sampler Return (0,) (575, 1, 7)
# Sampler Return (3359, 10, 20, 20) (3359, 10, 20, 1)
# Sampler Return (0,) (3359, 1, 48)
# Sampler Return (0,) (3359, 1, 7)
# Sampler Return (479, 10, 20, 20) (479, 10, 20, 1)
# Sampler Return (0,) (479, 1, 48)
# Sampler Return (0,) (479, 1, 7)
# Sampler Return (3263, 10, 20, 22) (3263, 10, 20, 1)
# Sampler Return (0,) (3263, 1, 48)
# Sampler Return (0,) (3263, 1, 7)
# Sampler Return (383, 10, 20, 22) (383, 10, 20, 1)
# Sampler Return (0,) (383, 1, 48)
# Sampler Return (0,) (383, 1, 7)
# Sampler Return (3167, 10, 20, 24) (3167, 10, 20, 1)
# Sampler Return (0,) (3167, 1, 48)
# Sampler Return (0,) (3167, 1, 7)
# Sampler Return (287, 10, 20, 24) (287, 10, 20, 1)
# Sampler Return (0,) (287, 1, 48)
# Sampler Return (0,) (287, 1, 7)

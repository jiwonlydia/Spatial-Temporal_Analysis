# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import os
import keras
import keras.backend as K
import random
import math

from keras import layers
from keras.layers import Input, Dense, Conv2D, AveragePooling2D, Conv2DTranspose, Activation
from keras.layers import concatenate, BatchNormalization, Dropout, Add, RepeatVector, Reshape
from keras.models import Model
from keras import regularizers

#from tensorflow.keras.optimizers import SGD , Adam
from keras.optimizers import SGD , Adam
# from keras.utils.training_utils import multi_gpu_model

# %% [markdown]
# # Arguments

# %%
import argparse
parser = argparse.ArgumentParser(description='')

parser.add_argument('--lr', type=float, default=0.01)
parser.add_argument('--decay', type=float, default=0.01)
parser.add_argument('--batch', type=int, default=128)
parser.add_argument('--epoch', type=int, default=1000)
parser.add_argument('--drop_p', type=float, default=0.1)
parser.add_argument('--reg', type=float, default=0.0)
parser.add_argument('--test', action='store_true')

parser.add_argument('--output_dir', type=str, default='./output/')
parser.add_argument('--save_dir', type=str, default='./model_saved/')
parser.add_argument('--model_name', type=str, default='no_named')

parser.add_argument('--scale', type=str, default='min_max')
parser.add_argument('--dataset_name', type=str, default='NYC')
parser.add_argument('--thr', type=int, default=10)
parser.add_argument('--alpha', type=float, default=0.05)
parser.add_argument('--num_gpu', type=int, default=1)
parser.add_argument('--coord', type=float, default=25.0)
parser.add_argument('--coord_net', type=int, default=2)

parser.add_argument('--temp', type=int, default=16)
parser.add_argument('--nf', type=int, default=32)
parser.add_argument('--enf', type=int, default=64)
parser.add_argument('--patience', type=int, default=150)
parser.add_argument('--es', type=str, default='min')

args, extras = parser.parse_known_args()

# %% [markdown]
# # Load Data

# %%
def load_np_data(filename):
    try:
        data = np.load(filename)['arr_0']
        print("[*] Success to load ", filename)
        return data
    except:
        raise IOError("Fail to load data", filename)

def get_min_max(data, scale='min_max'):
    if scale=='min_max':
        return np.min(data), np.max(data)
    else:
        return None, None
    
def min_max(data, min_value, max_value):
    result = data - min_value
    scale = max_value - min_value
    assert scale > 0
    result = result/scale
    return result

def scaler(data, scale_type='log', inv=False, min_value=None, max_value=None):
    if scale_type == 'log':
        if not inv:
            print("[*] ", np.shape(data), ":log scaled")
            return logscale(data)
        else:
            print("[*] ", np.shape(data), ": inverse log scaled")
            return inverse_logscale(data)
    elif scale_type == 'min_max':
        assert (min_value != None) and (max_value != None)
        if not inv:
            return min_max(data, min_value, max_value)
        else:
            return inverse_min_max(data, min_value, max_value)
    else:
        print("[!] invalid scale type: ", scale_type)
        raise
        
def inverse_min_max(data, min_value, max_value):
    scale = max_value - min_value
    result = scale * data + min_value
    return result

# %%
def LoadData(STAMP, LAG, STEP, train=True, valid=False):
    
#     args.model_name = f'SeoulFloatingPop_lag{LAG}_step{STEP}'

    ### train set

    x_train = load_np_data(f'./data/x_train_stamp{STAMP}_lag{LAG}.npz')
    min_x, max_x = get_min_max(x_train, 'min_max')

    if train:    
        y_train = load_np_data(f'./data/y_train_stamp{STAMP}_lag{LAG}.npz')
        temporal_train = load_np_data(f'./data/temporal_train_stamp{STAMP}_lag{LAG}.npz')
        temporal_train = temporal_train.reshape(temporal_train.shape[0],temporal_train.shape[2])
        
        # Min Max Scaling
        x_train = scaler(x_train, 'min_max', inv=False, min_value=min_x, max_value=max_x)
        y_train = scaler(y_train, 'min_max', inv=False, min_value=min_x, max_value=max_x)
        
        ### validation set
        valid_ratio=0.2
        num_train = int(len(x_train)*(1.0-valid_ratio))
        x_train, x_valid = x_train[:num_train], x_train[num_train:]
        temporal_train, temporal_valid = temporal_train[:num_train], temporal_train[num_train:]
        y_train, y_valid = y_train[:num_train], y_train[num_train:]
        
        if valid:
            
            print(f'x_valid.shape = {x_valid.shape}')
            print(f'y_valid.shape = {y_valid.shape}')
            print(f'temporal_valid.shape = {temporal_valid.shape}')
        
            return x_valid, temporal_valid, y_valid
            
        else:
            
            print('--- training dataset ---')
            print(f'x_train.shape = {x_train.shape}')
            print(f'y_train.shape = {y_train.shape}')
            print(f'temporal_train.shape = {temporal_train.shape}')

            return x_train, temporal_train, y_train
    
    else: ### test set

        x_test = load_np_data(f'./data/x_test_stamp{STAMP}_lag{LAG}_step{STEP}.npz')
        y_test = load_np_data(f'./data/y_test_stamp{STAMP}_lag{LAG}_step{STEP}.npz')
        temporal_test = load_np_data(f'./data/temporal_test_stamp{STAMP}_lag{LAG}_step{STEP}.npz')

        # Min Max Scaling
        x_test = scaler(x_test, 'min_max', inv=False, min_value=min_x, max_value=max_x)
        y_test = scaler(y_test, 'min_max', inv=False, min_value=min_x, max_value=max_x)

        print('--- test dataset ---')
        print(f'x_test.shape = {x_test.shape}')
        print(f'y_test.shape = {y_test.shape}')
        print(f'temporal_test.shape = {temporal_test.shape}')

        return x_test, temporal_test, y_test

# %% [markdown]
# # TGNet

# %%
def rmse(y_true, y_pred):
    rtn = np.sqrt(  np.average( np.square(y_pred-y_true) ) )
    return  rtn

def mape(y_true,y_pred):
    rtn = np.mean(np.abs((y_true - y_pred) / (1.0+y_true)))
    return rtn

def mape_trs(y_true,y_pred, trs=0):
    true_mask = y_true > trs
    tmp_abs = np.divide(np.abs(y_true-y_pred)[true_mask] , y_true[true_mask])

    rtn = (np.average(tmp_abs))
    return rtn

def rmse_trs(y_true,y_pred, trs=0):
    true_mask = y_true > trs
    tmp_abs = np.sqrt(np.average(np.square(y_pred-y_true)[true_mask]))
    return tmp_abs

# %%
def gn_block(input, num_c=64, kernel_size=(3,3), strides=(1,1), padding='SAME', activation='relu', dropout=None, regularizer=0.01):
    net = AveragePooling2D(kernel_size, strides, padding)(input)
    net = Conv2D(num_c, kernel_size=(1,1), strides=strides, activation='linear', padding=padding, kernel_regularizer=regularizers.l1(regularizer))(net)

    net_sf = Conv2D(num_c, kernel_size=(1,1), strides=strides, activation='linear', padding=padding, kernel_regularizer=regularizers.l1(regularizer))(input)

    net = Add()([net, net_sf])
    net = concatenate([input, net])
    net = Conv2D(num_c, kernel_size=(1,1), strides=strides, activation=activation, padding=padding, kernel_regularizer=regularizers.l1(regularizer))(net)
    net = BatchNormalization()(net)

    if dropout == None:
        return net
    else:
        net = Dropout(dropout)(net)
        return net

def deconv_block(input, num_c=64, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu', dropout=None, regularizer=0.01):
    net = Conv2DTranspose(num_c, kernel_size=kernel_size, strides=strides, activation=activation, padding=padding, kernel_regularizer=regularizers.l1(regularizer))(input)
    net = BatchNormalization()(net)
    if dropout == None:
        return net
    else:
        net = Dropout(dropout)(net)
        return net

# %%
def TGNet(input_shape):
    nf = args.nf
    h,w = input_shape[:2]
    start_input = Input(shape=input_shape)
    temporal_input = Input(shape=(55,))
    input_tensors = [start_input, temporal_input]


    ### Temporal guided embedding
    net_temp = Dense(args.temp, activation='relu')(temporal_input)
    # self.net_temp = Dense(args.temp, activation='relu')(net_temp)
    net_temp = RepeatVector(h*w)(net_temp)
    net_temp = Reshape((h,w,args.temp))(net_temp)

    ### U-net layers
    net1 = concatenate([start_input, net_temp], axis=-1)
    net1 = gn_block(net1, nf, dropout=args.drop_p,regularizer=args.reg)
    net11 = AveragePooling2D(pool_size=(2,2))(net1)
    net2 = gn_block(net11, nf*2,  dropout=args.drop_p, regularizer=args.reg)
    net3 = gn_block(net2, nf*2,  dropout=args.drop_p, regularizer=args.reg)
    net33 = concatenate([net2, net3])
    net4 = gn_block(net33, nf*2,  dropout=args.drop_p, regularizer=args.reg)
    net4 = concatenate([net2, net3, net4])

    net5 = deconv_block(net4, nf*4, (2,2), (2,2),   dropout=args.drop_p,regularizer=args.reg)
    net5 = concatenate([net5, net1])
    net6 = deconv_block(net5, nf*4, (3,3), (1,1), 'same',  dropout=args.drop_p, regularizer=args.reg)

    ## Position-wise Regression
    net7 = concatenate([net6, start_input, net_temp], axis=-1)
    net7 = gn_block(net7, nf*4, kernel_size=(1,1), dropout=args.drop_p, regularizer=args.reg)

    output = Conv2D(1, kernel_size=(1,1), padding='same', kernel_regularizer=regularizers.l2(args.reg))(net7)
    output = Activation('relu')(output)

    model = Model(inputs=input_tensors, outputs=output)

    return model

# %%
def train(STAMP, LAG, STEP):

    x_train, temporal_train, y_train = LoadData(STAMP=STAMP, LAG=LAG, STEP=STEP, train=True, valid=False)
    x_valid, temporal_valid, y_valid = LoadData(STAMP=STAMP, LAG=LAG, STEP=STEP, train=True, valid=True)

    input_shape = [10, 20, LAG]
    model = TGNet(input_shape)

    model.compile(loss=['mean_absolute_error'], 
               optimizer=Adam(lr=0.001, decay=args.decay), 
               metrics=['mean_absolute_error'])

    
    print('===== START TRAINGING =====')
    
#     with tf.device('/CPU:0'): # 텐서를 CPU에 할당
    best_eval_loss = 100000
    patience = 0

    for idx in range(args.epoch): # epoch

        print(f'Epoch = {idx}')
        model.fit([x_train, temporal_train], y_train, 
                  batch_size=args.batch, epochs=1, shuffle=True,verbose=2)

        eval_loss = model.evaluate([x_valid, temporal_valid], y_valid, 
                                   batch_size=args.batch, verbose=2)
        patience += 1
        if patience > args.patience:
            break

        if best_eval_loss > eval_loss[-1]:
            if not os.path.exists('./model_saved'):
                os.mkdir('./model_saved')
            else:
                model.save(f'./model_saved/best_model_stamp{STAMP}_lag{LAG}.h5')

            best_eval_loss = eval_loss[-1]
            patience = 0
    print('===== END TRAINGING =====')

# %%
def flatten_result(data):
    num_row, h, w = data.shape[:3]
    num_col = int(h*w)
    return np.reshape(data, [num_row, num_col])

def save_test_output(pred_inverse, y_inverse, output_path=None):
    num_row, h, w = pred_inverse.shape[:3]
    num_col = int(h*w)
    assert pred_inverse.shape[:3] == y_inverse.shape[:3]
    if output_path == None:
        output_path = './model_output/temporal_directory'
        print("[!] Please Assign Output Path in Arguments")

    np_pred = flatten_result(pred_inverse) #np.reshape(pred_inverse, [num_row, num_col])
    np_y = flatten_result(y_inverse) #np.reshape(y_inverse, [num_row, num_col])

    col_name = ['col_'+str(i) for i in range(0, num_col)]
    index = np.arange(0, num_row)
    df_pred = pd.DataFrame(np_pred, columns=col_name, index=index)
    df_y = pd.DataFrame(np_y, columns=col_name, index=index)

    df_y.to_csv(output_path+'_gt.csv', index=False)
    df_pred.to_csv(output_path+'_pred.csv', index=False)

# %% [markdown]
# # Forecasting

# %%
def single_step_forecast(STAMP, LAG):
    # Load saved model
    model = tf.keras.models.load_model(f'./model_saved/best_model_stamp{STAMP}_lag{LAG}.h5')
    print(f'Model Loaded: best_model_stamp{STAMP}_lag{LAG}.h5')
    
    min_x, max_x = get_min_max(load_np_data(f'./data/x_train_stamp{STAMP}_lag{LAG}.npz'), 'min_max')
    x_test, temporal_test, y_test = LoadData(STAMP=STAMP, LAG=LAG, STEP=1, train=False, valid=False)
    
    temporal_test_step1 = temporal_test[:,0,:]
    y_pred =  model.predict([x_test, temporal_test_step1]) ; print(y_pred.sum())
    y_true = np.expand_dims(y_test[:,:,:,0], axis=-1)
    y_pred_inv = scaler(y_pred, 'min_max', inv=True, min_value=min_x, max_value=max_x)
    y_true_inv = scaler(y_true, 'min_max', inv=True, min_value=min_x, max_value=max_x)    
    save_test_output(y_pred_inv, y_true_inv, output_path=f'./output/predictions/stamp{STAMP}_lag{LAG}_step1')
    RMSE = rmse(y_true_inv, y_pred_inv)
    print(RMSE)
    return RMSE

# %%
def multi_step_forecast(STAMP, LAG, STEP):
    
    # Load saved model
    model = tf.keras.models.load_model(f'./model_saved/best_model_stamp{STAMP}_lag{LAG}.h5')
    print(f'Model Loaded: best_model_stamp{STAMP}_lag{LAG}.h5')
    min_x, max_x = get_min_max(load_np_data(f'./data/x_train_stamp{STAMP}_lag{LAG}.npz'), 'min_max')
    x_test, temporal_test, y_test = LoadData(STAMP=STAMP, LAG=LAG, STEP=STEP, train=False, valid=False)

    rmse_list = []

    # Single-Step Forecast
    temporal_test_step1 = temporal_test[:,0,:]
    y_pred =  model.predict([x_test, temporal_test_step1])
    y_true = np.expand_dims(y_test[:,:,:,0], axis=-1)

    y_pred_inv = scaler(y_pred, 'min_max', inv=True, min_value=min_x, max_value=max_x)
    y_true_inv = scaler(y_true, 'min_max', inv=True, min_value=min_x, max_value=max_x)    
    save_test_output(y_pred_inv, y_true_inv, output_path=f'./output/predictions/stamp{STAMP}_lag{LAG}_step1')
    
    RMSE = rmse(y_true_inv, y_pred_inv)
    rmse_list.append(RMSE)
    print(f'RMSE of Single-Step Forecast = {RMSE:3.3f}')

    y_pred_new = y_pred
    for h in range(2,STEP+1):

        # Multi-Step Forecast (h-step)
        temporal_test_h = temporal_test[:,h-1,:]
        if h > LAG:
            x_test_new = y_pred_new[:,:,:,h-LAG-1:h-1]
        else:
            x_test_new = np.concatenate([x_test[:,:,:,h-1:], y_pred_new], axis=-1)
        print(x_test_new.shape)
    #     with tf.device('/CPU:0'): # 텐서를 CPU에 할당
        y_pred = model.predict([x_test_new, temporal_test_h])
        y_pred_new = np.concatenate([y_pred_new, y_pred], axis=-1)
        y_true = np.expand_dims(y_test[:,:,:,h-1], axis=-1)

        y_pred_inv = scaler(y_pred, 'min_max', inv=True, min_value=min_x, max_value=max_x)
        y_true_inv = scaler(y_true, 'min_max', inv=True, min_value=min_x, max_value=max_x)
        save_test_output(y_pred_inv, y_true_inv, output_path=f'./output/predictions/stamp{STAMP}_lag{LAG}_step{h}')
        RMSE = rmse(y_true_inv, y_pred_inv)
        rmse_list.append(RMSE)
        print(f'RMSE of {h}-Step Forecast = {RMSE:3.3f}')
        
        if not os.path.exists('./output/metric'):
            os.mkdir('./output/metric')
        index = np.arange(0, len(rmse_list))
        df_rmse = pd.DataFrame(rmse_list, columns=['RMSE'], index=index)
        df_rmse.to_csv('./output/metric/' + f'rmse_stamp{STAMP}_lag{LAG}_step{STEP}.csv')
        
        plt.plot(df_rmse)
        plt.title(f'RMSE of {STEP}-step ahead prediction: Stamp={STAMP}, lag={LAG}')

    return rmse_list[-1]

# %% [markdown]
# ### single-step forecast

# %%
args.epoch = 1000
print(args.epoch)

# train
stamp = 1; lag = 10 ; step = 1

# train(STAMP=stamp, LAG=lag, STEP=step)
single_step_forecast(STAMP=stamp, LAG=lag)
# Out:
# 1000
# 2022-09-28 21:52:27.133272: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-28 21:52:28.297609: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9378 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:03:00.0, compute capability: 7.5
# 2022-09-28 21:52:28.298667: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9335 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:05:00.0, compute capability: 7.5
# Model Loaded: best_model_stamp1_lag10.h5
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in load_np_data(filename)
#       2 try:
# ----> 3     data = np.load(filename)['arr_0']
#       4     print("[*] Success to load ", filename)
#
# File ~/miniconda3/lib/python3.8/site-packages/numpy/lib/npyio.py:390, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     389 else:
# --> 390     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     391     own_fid = True
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/x_train_stamp1_lag10.npz'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Input In [12], in <cell line: 8>()
#       5 stamp = 1; lag = 10 ; step = 1
#       7 # train(STAMP=stamp, LAG=lag, STEP=step)
# ----> 8 single_step_forecast(STAMP=stamp, LAG=lag)
#
# Input In [10], in single_step_forecast(STAMP, LAG)
#       3 model = tf.keras.models.load_model(f'./model_saved/best_model_stamp{STAMP}_lag{LAG}.h5')
#       4 print(f'Model Loaded: best_model_stamp{STAMP}_lag{LAG}.h5')
# ----> 6 min_x, max_x = get_min_max(load_np_data(f'./data/x_train_stamp{STAMP}_lag{LAG}.npz'), 'min_max')
#       7 x_test, temporal_test, y_test = LoadData(STAMP=STAMP, LAG=LAG, STEP=1, train=False, valid=False)
#       9 temporal_test_step1 = temporal_test[:,0,:]
#
# Input In [3], in load_np_data(filename)
#       5     return data
#       6 except:
# ----> 7     raise IOError("Fail to load data", filename)
#
# OSError: [Errno Fail to load data] ./data/x_train_stamp1_lag10.npz

# %% [markdown]
# ### multi-step forecast (Recursive Method)

# %% [markdown]
# ## Tuning the time unit of training data (Direct Method)

# %%
time_unit = [0.5,1,2,3,4,6,8,12,24]
stamp_list = [int(2*i) for i in time_unit]
step_list = [int(48/i) for i in stamp_list]
lag_list = [2*(i+1) for i in range(12)]

# %%
table = np.zeros(shape=(len(time_unit),len(lag_list)))

for i in range(len(time_unit)): # time unit에 따라
    for j in range(len(lag_list)): # lag에 따라
#         train(STAMP=stamp_list[i], LAG=lag_list[j], STEP=step_list[i])        
        table[i,j] = multi_step_forecast(STAMP=stamp_list[i], LAG=lag_list[j], STEP=step_list[i])
# Out:
# Model Loaded: best_model_stamp1_lag2.h5
# [*] Success to load  ./data/x_train_stamp1_lag2.npz
# [*] Success to load  ./data/x_train_stamp1_lag2.npz
# [*] Success to load  ./data/x_test_stamp1_lag2_step48.npz
# [*] Success to load  ./data/y_test_stamp1_lag2_step48.npz
# [*] Success to load  ./data/temporal_test_stamp1_lag2_step48.npz
# --- test dataset ---
# x_test.shape = (1390, 10, 20, 2)
# y_test.shape = (1390, 10, 20, 48)
# temporal_test.shape = (1390, 48, 55)
# 2022-09-29 01:01:06.529429: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8400
# 2022-09-29 01:01:07.238742: E tensorflow/stream_executor/gpu/asm_compiler.cc:105] You are using ptxas 8.x, but TF requires ptxas 9.x (and strongly prefers >= 11.1).  Compilation of XLA kernels below will likely fail.
#
# You may not need to update CUDA; cherry-picking the ptxas binary is often sufficient.
# 2022-09-29 01:01:07.331592: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 7.5
# 2022-09-29 01:01:07.331651: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2022-09-29 01:01:07.331740: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 44/44 [==============================] - 3s 8ms/step
# RMSE of Single-Step Forecast = 6.049
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 2-Step Forecast = 7.647
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 3-Step Forecast = 9.049
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 4-Step Forecast = 10.225
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 5-Step Forecast = 11.257
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 6-Step Forecast = 12.242
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 7-Step Forecast = 13.108
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 8-Step Forecast = 13.901
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 9-Step Forecast = 14.601
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 10-Step Forecast = 15.272
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 11-Step Forecast = 15.935
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 12-Step Forecast = 16.603
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 13-Step Forecast = 17.232
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 14-Step Forecast = 17.825
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 15-Step Forecast = 18.360
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 16-Step Forecast = 18.833
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 17-Step Forecast = 19.248
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 18-Step Forecast = 19.634
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 19-Step Forecast = 20.025
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 20-Step Forecast = 20.391
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 21-Step Forecast = 20.732
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 22-Step Forecast = 21.034
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 23-Step Forecast = 21.298
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 24-Step Forecast = 21.540
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 25-Step Forecast = 21.767
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 26-Step Forecast = 21.943
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 27-Step Forecast = 22.088
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 28-Step Forecast = 22.189
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 29-Step Forecast = 22.249
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 30-Step Forecast = 22.260
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 31-Step Forecast = 22.261
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 32-Step Forecast = 22.233
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 33-Step Forecast = 22.184
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 34-Step Forecast = 22.114
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 35-Step Forecast = 22.023
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 36-Step Forecast = 21.939
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 37-Step Forecast = 21.852
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 38-Step Forecast = 21.797
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 39-Step Forecast = 21.772
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 40-Step Forecast = 21.773
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 41-Step Forecast = 21.791
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 42-Step Forecast = 21.836
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 43-Step Forecast = 21.885
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 44-Step Forecast = 21.939
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 45-Step Forecast = 22.023
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 46-Step Forecast = 22.123
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 47-Step Forecast = 22.223
# (1390, 10, 20, 2)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 48-Step Forecast = 22.339
# Model Loaded: best_model_stamp1_lag4.h5
# [*] Success to load  ./data/x_train_stamp1_lag4.npz
# [*] Success to load  ./data/x_train_stamp1_lag4.npz
# [*] Success to load  ./data/x_test_stamp1_lag4_step48.npz
# [*] Success to load  ./data/y_test_stamp1_lag4_step48.npz
# [*] Success to load  ./data/temporal_test_stamp1_lag4_step48.npz
# --- test dataset ---
# x_test.shape = (1388, 10, 20, 4)
# y_test.shape = (1388, 10, 20, 48)
# temporal_test.shape = (1388, 48, 55)
# 44/44 [==============================] - 1s 8ms/step
# RMSE of Single-Step Forecast = 6.160
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 2-Step Forecast = 8.078
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 3-Step Forecast = 9.852
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 4-Step Forecast = 10.942
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 5-Step Forecast = 11.824
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 6-Step Forecast = 12.576
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 7-Step Forecast = 13.248
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 8-Step Forecast = 13.864
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 9-Step Forecast = 14.445
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 10-Step Forecast = 15.003
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 4ms/step
# RMSE of 11-Step Forecast = 15.574
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 12-Step Forecast = 16.176
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 13-Step Forecast = 16.778
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 14-Step Forecast = 17.332
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 15-Step Forecast = 17.848
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 16-Step Forecast = 18.309
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 17-Step Forecast = 18.727
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 18-Step Forecast = 19.124
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 19-Step Forecast = 19.519
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 20-Step Forecast = 19.887
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 21-Step Forecast = 20.268
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 22-Step Forecast = 20.615
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 23-Step Forecast = 20.946
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 24-Step Forecast = 21.250
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 25-Step Forecast = 21.562
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 26-Step Forecast = 21.832
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 27-Step Forecast = 22.063
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 28-Step Forecast = 22.255
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 29-Step Forecast = 22.413
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 30-Step Forecast = 22.534
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 31-Step Forecast = 22.639
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 32-Step Forecast = 22.693
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 33-Step Forecast = 22.712
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 34-Step Forecast = 22.687
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 35-Step Forecast = 22.637
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 36-Step Forecast = 22.594
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 37-Step Forecast = 22.576
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 38-Step Forecast = 22.576
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 39-Step Forecast = 22.608
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 40-Step Forecast = 22.683
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 41-Step Forecast = 22.784
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 42-Step Forecast = 22.899
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 43-Step Forecast = 23.008
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 44-Step Forecast = 23.088
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 45-Step Forecast = 23.175
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 46-Step Forecast = 23.269
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 47-Step Forecast = 23.371
# (1388, 10, 20, 4)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 48-Step Forecast = 23.473
# Model Loaded: best_model_stamp1_lag6.h5
# [*] Success to load  ./data/x_train_stamp1_lag6.npz
# [*] Success to load  ./data/x_train_stamp1_lag6.npz
# [*] Success to load  ./data/x_test_stamp1_lag6_step48.npz
# [*] Success to load  ./data/y_test_stamp1_lag6_step48.npz
# [*] Success to load  ./data/temporal_test_stamp1_lag6_step48.npz
# --- test dataset ---
# x_test.shape = (1386, 10, 20, 6)
# y_test.shape = (1386, 10, 20, 48)
# temporal_test.shape = (1386, 48, 55)
# 44/44 [==============================] - 1s 7ms/step
# RMSE of Single-Step Forecast = 6.176
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 2-Step Forecast = 7.809
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 3-Step Forecast = 9.310
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 4-Step Forecast = 10.366
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 5-Step Forecast = 11.327
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 6-Step Forecast = 12.164
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 7-Step Forecast = 12.951
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 8-Step Forecast = 13.694
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 9-Step Forecast = 14.381
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 10-Step Forecast = 15.030
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 11-Step Forecast = 15.671
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 12-Step Forecast = 16.325
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 13-Step Forecast = 16.956
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 14-Step Forecast = 17.550
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 15-Step Forecast = 18.099
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 16-Step Forecast = 18.609
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 17-Step Forecast = 19.075
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 18-Step Forecast = 19.520
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 19-Step Forecast = 19.953
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 20-Step Forecast = 20.372
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 21-Step Forecast = 20.786
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 22-Step Forecast = 21.178
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 23-Step Forecast = 21.570
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 24-Step Forecast = 21.975
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 25-Step Forecast = 22.373
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 26-Step Forecast = 22.711
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 27-Step Forecast = 22.997
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 28-Step Forecast = 23.228
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 29-Step Forecast = 23.412
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 30-Step Forecast = 23.557
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 31-Step Forecast = 23.681
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 32-Step Forecast = 23.772
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 33-Step Forecast = 23.825
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 34-Step Forecast = 23.850
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 35-Step Forecast = 23.865
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 36-Step Forecast = 23.876
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 37-Step Forecast = 23.883
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 38-Step Forecast = 23.893
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 39-Step Forecast = 23.915
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 40-Step Forecast = 23.937
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 41-Step Forecast = 23.965
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 42-Step Forecast = 23.988
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 43-Step Forecast = 24.010
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 44-Step Forecast = 24.040
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 45-Step Forecast = 24.071
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 46-Step Forecast = 24.108
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 47-Step Forecast = 24.145
# (1386, 10, 20, 6)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 48-Step Forecast = 24.186
# Model Loaded: best_model_stamp1_lag8.h5
# [*] Success to load  ./data/x_train_stamp1_lag8.npz
# [*] Success to load  ./data/x_train_stamp1_lag8.npz
# [*] Success to load  ./data/x_test_stamp1_lag8_step48.npz
# [*] Success to load  ./data/y_test_stamp1_lag8_step48.npz
# [*] Success to load  ./data/temporal_test_stamp1_lag8_step48.npz
# --- test dataset ---
# x_test.shape = (1384, 10, 20, 8)
# y_test.shape = (1384, 10, 20, 48)
# temporal_test.shape = (1384, 48, 55)
# 44/44 [==============================] - 1s 8ms/step
# RMSE of Single-Step Forecast = 6.610
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 2-Step Forecast = 8.671
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 3-Step Forecast = 10.198
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 4-Step Forecast = 11.099
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 5-Step Forecast = 12.077
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 6-Step Forecast = 13.079
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 7-Step Forecast = 14.016
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 8-Step Forecast = 14.773
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 9-Step Forecast = 15.381
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 10-Step Forecast = 15.941
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 11-Step Forecast = 16.486
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 12-Step Forecast = 17.047
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 13-Step Forecast = 17.570
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 14-Step Forecast = 18.063
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 15-Step Forecast = 18.534
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 16-Step Forecast = 18.966
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 17-Step Forecast = 19.360
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 18-Step Forecast = 19.739
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 19-Step Forecast = 20.097
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 20-Step Forecast = 20.458
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 21-Step Forecast = 20.828
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 22-Step Forecast = 21.176
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 23-Step Forecast = 21.520
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 24-Step Forecast = 21.856
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 25-Step Forecast = 22.189
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 26-Step Forecast = 22.503
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 27-Step Forecast = 22.777
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 28-Step Forecast = 23.002
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 29-Step Forecast = 23.181
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 30-Step Forecast = 23.326
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 31-Step Forecast = 23.444
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 32-Step Forecast = 23.534
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 33-Step Forecast = 23.614
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 34-Step Forecast = 23.663
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 35-Step Forecast = 23.692
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 36-Step Forecast = 23.713
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 37-Step Forecast = 23.739
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 38-Step Forecast = 23.767
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 39-Step Forecast = 23.799
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 40-Step Forecast = 23.827
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 41-Step Forecast = 23.858
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 42-Step Forecast = 23.890
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 43-Step Forecast = 23.920
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 44-Step Forecast = 23.949
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 45-Step Forecast = 23.975
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 46-Step Forecast = 24.003
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 47-Step Forecast = 24.032
# (1384, 10, 20, 8)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 48-Step Forecast = 24.057
# Model Loaded: best_model_stamp1_lag10.h5
# [*] Success to load  ./data/x_train_stamp1_lag10.npz
# [*] Success to load  ./data/x_train_stamp1_lag10.npz
# [*] Success to load  ./data/x_test_stamp1_lag10_step48.npz
# [*] Success to load  ./data/y_test_stamp1_lag10_step48.npz
# [*] Success to load  ./data/temporal_test_stamp1_lag10_step48.npz
# --- test dataset ---
# x_test.shape = (1382, 10, 20, 10)
# y_test.shape = (1382, 10, 20, 48)
# temporal_test.shape = (1382, 48, 55)
# 44/44 [==============================] - 1s 8ms/step
# RMSE of Single-Step Forecast = 6.498
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 2-Step Forecast = 8.518
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 3-Step Forecast = 10.036
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 4-Step Forecast = 11.132
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 5-Step Forecast = 11.956
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 6-Step Forecast = 12.732
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 7-Step Forecast = 13.528
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 8-Step Forecast = 14.191
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 9-Step Forecast = 14.808
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 10-Step Forecast = 15.369
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 11-Step Forecast = 15.867
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 12-Step Forecast = 16.388
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 13-Step Forecast = 16.906
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 14-Step Forecast = 17.408
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 15-Step Forecast = 17.882
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 16-Step Forecast = 18.341
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 17-Step Forecast = 18.783
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 18-Step Forecast = 19.203
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 19-Step Forecast = 19.625
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 20-Step Forecast = 20.045
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 21-Step Forecast = 20.486
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 22-Step Forecast = 20.917
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 23-Step Forecast = 21.329
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 4ms/step
# RMSE of 24-Step Forecast = 21.705
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 25-Step Forecast = 22.068
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 26-Step Forecast = 22.405
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 27-Step Forecast = 22.715
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 28-Step Forecast = 23.001
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 29-Step Forecast = 23.230
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 30-Step Forecast = 23.414
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 31-Step Forecast = 23.579
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 32-Step Forecast = 23.712
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 33-Step Forecast = 23.822
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 34-Step Forecast = 23.912
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 35-Step Forecast = 23.973
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 36-Step Forecast = 24.017
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 37-Step Forecast = 24.050
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 38-Step Forecast = 24.078
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 39-Step Forecast = 24.105
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 40-Step Forecast = 24.137
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 41-Step Forecast = 24.166
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 42-Step Forecast = 24.185
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 43-Step Forecast = 24.205
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 44-Step Forecast = 24.223
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 45-Step Forecast = 24.238
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 46-Step Forecast = 24.252
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 47-Step Forecast = 24.266
# (1382, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 48-Step Forecast = 24.278
# Model Loaded: best_model_stamp1_lag12.h5
# [*] Success to load  ./data/x_train_stamp1_lag12.npz
# [*] Success to load  ./data/x_train_stamp1_lag12.npz
# [*] Success to load  ./data/x_test_stamp1_lag12_step48.npz
# [*] Success to load  ./data/y_test_stamp1_lag12_step48.npz
# [*] Success to load  ./data/temporal_test_stamp1_lag12_step48.npz
# --- test dataset ---
# x_test.shape = (1380, 10, 20, 12)
# y_test.shape = (1380, 10, 20, 48)
# temporal_test.shape = (1380, 48, 55)
# 44/44 [==============================] - 1s 8ms/step
# RMSE of Single-Step Forecast = 6.046
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 2-Step Forecast = 7.638
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 3-Step Forecast = 9.051
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 4-Step Forecast = 10.037
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 5-Step Forecast = 10.958
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 6-Step Forecast = 11.812
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 7-Step Forecast = 12.638
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 8-Step Forecast = 13.414
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 9-Step Forecast = 14.193
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 10-Step Forecast = 14.903
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 11-Step Forecast = 15.619
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 12-Step Forecast = 16.308
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 13-Step Forecast = 16.939
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 14-Step Forecast = 17.529
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 15-Step Forecast = 18.077
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 16-Step Forecast = 18.589
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 17-Step Forecast = 19.082
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 18-Step Forecast = 19.544
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 19-Step Forecast = 19.997
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 20-Step Forecast = 20.445
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 21-Step Forecast = 20.897
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 22-Step Forecast = 21.350
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 23-Step Forecast = 21.786
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 24-Step Forecast = 22.193
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 25-Step Forecast = 22.589
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 26-Step Forecast = 22.938
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 27-Step Forecast = 23.219
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 28-Step Forecast = 23.459
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 29-Step Forecast = 23.658
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 30-Step Forecast = 23.830
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 31-Step Forecast = 23.968
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 32-Step Forecast = 24.075
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 33-Step Forecast = 24.153
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 34-Step Forecast = 24.204
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 35-Step Forecast = 24.242
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 36-Step Forecast = 24.265
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 37-Step Forecast = 24.280
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 38-Step Forecast = 24.293
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 39-Step Forecast = 24.307
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 40-Step Forecast = 24.319
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 41-Step Forecast = 24.330
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 42-Step Forecast = 24.342
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 43-Step Forecast = 24.353
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 44-Step Forecast = 24.363
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 45-Step Forecast = 24.373
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 46-Step Forecast = 24.382
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 47-Step Forecast = 24.389
# (1380, 10, 20, 12)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 48-Step Forecast = 24.397
# Model Loaded: best_model_stamp1_lag14.h5
# [*] Success to load  ./data/x_train_stamp1_lag14.npz
# [*] Success to load  ./data/x_train_stamp1_lag14.npz
# [*] Success to load  ./data/x_test_stamp1_lag14_step48.npz
# [*] Success to load  ./data/y_test_stamp1_lag14_step48.npz
# [*] Success to load  ./data/temporal_test_stamp1_lag14_step48.npz
# --- test dataset ---
# x_test.shape = (1378, 10, 20, 14)
# y_test.shape = (1378, 10, 20, 48)
# temporal_test.shape = (1378, 48, 55)
# 44/44 [==============================] - 1s 8ms/step
# RMSE of Single-Step Forecast = 6.007
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 2-Step Forecast = 7.634
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 3-Step Forecast = 8.994
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 4-Step Forecast = 9.990
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 5-Step Forecast = 10.928
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 6-Step Forecast = 11.783
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 7-Step Forecast = 12.670
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 8-Step Forecast = 13.470
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 9-Step Forecast = 14.251
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 10-Step Forecast = 14.945
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 11-Step Forecast = 15.627
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 12-Step Forecast = 16.317
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 13-Step Forecast = 17.003
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 14-Step Forecast = 17.598
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 15-Step Forecast = 18.134
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 16-Step Forecast = 18.638
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 17-Step Forecast = 19.108
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 18-Step Forecast = 19.556
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 19-Step Forecast = 19.983
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 20-Step Forecast = 20.385
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 21-Step Forecast = 20.788
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 22-Step Forecast = 21.188
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 23-Step Forecast = 21.587
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 24-Step Forecast = 21.989
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 25-Step Forecast = 22.385
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 26-Step Forecast = 22.732
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 27-Step Forecast = 23.026
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 28-Step Forecast = 23.276
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 29-Step Forecast = 23.491
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 30-Step Forecast = 23.677
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 31-Step Forecast = 23.835
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 32-Step Forecast = 23.964
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 33-Step Forecast = 24.060
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 34-Step Forecast = 24.134
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 35-Step Forecast = 24.185
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 36-Step Forecast = 24.227
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 37-Step Forecast = 24.251
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 38-Step Forecast = 24.264
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 39-Step Forecast = 24.278
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 40-Step Forecast = 24.296
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 41-Step Forecast = 24.315
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 42-Step Forecast = 24.334
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 43-Step Forecast = 24.347
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 44-Step Forecast = 24.360
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 45-Step Forecast = 24.372
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 46-Step Forecast = 24.384
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 47-Step Forecast = 24.395
# (1378, 10, 20, 14)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 48-Step Forecast = 24.404
# Model Loaded: best_model_stamp1_lag16.h5
# [*] Success to load  ./data/x_train_stamp1_lag16.npz
# [*] Success to load  ./data/x_train_stamp1_lag16.npz
# [*] Success to load  ./data/x_test_stamp1_lag16_step48.npz
# [*] Success to load  ./data/y_test_stamp1_lag16_step48.npz
# [*] Success to load  ./data/temporal_test_stamp1_lag16_step48.npz
# --- test dataset ---
# x_test.shape = (1376, 10, 20, 16)
# y_test.shape = (1376, 10, 20, 48)
# temporal_test.shape = (1376, 48, 55)
# 43/43 [==============================] - 1s 6ms/step
# RMSE of Single-Step Forecast = 6.331
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 2-Step Forecast = 8.090
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 3-Step Forecast = 9.381
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 4-Step Forecast = 10.316
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 5-Step Forecast = 11.160
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 6-Step Forecast = 11.974
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 7-Step Forecast = 12.829
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 8-Step Forecast = 13.639
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 9-Step Forecast = 14.404
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 10-Step Forecast = 15.084
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 11-Step Forecast = 15.745
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 12-Step Forecast = 16.412
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 13-Step Forecast = 17.045
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 14-Step Forecast = 17.608
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 15-Step Forecast = 18.120
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 16-Step Forecast = 18.575
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 17-Step Forecast = 18.994
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 18-Step Forecast = 19.394
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 19-Step Forecast = 19.800
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 20-Step Forecast = 20.200
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 21-Step Forecast = 20.619
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 22-Step Forecast = 21.032
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 23-Step Forecast = 21.425
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 24-Step Forecast = 21.794
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 25-Step Forecast = 22.145
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 26-Step Forecast = 22.474
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 27-Step Forecast = 22.775
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 28-Step Forecast = 23.049
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 29-Step Forecast = 23.276
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 30-Step Forecast = 23.462
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 31-Step Forecast = 23.612
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 32-Step Forecast = 23.731
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 33-Step Forecast = 23.833
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 34-Step Forecast = 23.912
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 35-Step Forecast = 23.971
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 36-Step Forecast = 24.014
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 37-Step Forecast = 24.045
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 38-Step Forecast = 24.076
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 39-Step Forecast = 24.109
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 40-Step Forecast = 24.139
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 41-Step Forecast = 24.174
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 42-Step Forecast = 24.205
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 43-Step Forecast = 24.230
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 44-Step Forecast = 24.253
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 45-Step Forecast = 24.276
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 46-Step Forecast = 24.299
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 47-Step Forecast = 24.321
# (1376, 10, 20, 16)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 48-Step Forecast = 24.342
# Model Loaded: best_model_stamp1_lag18.h5
# [*] Success to load  ./data/x_train_stamp1_lag18.npz
# [*] Success to load  ./data/x_train_stamp1_lag18.npz
# [*] Success to load  ./data/x_test_stamp1_lag18_step48.npz
# [*] Success to load  ./data/y_test_stamp1_lag18_step48.npz
# [*] Success to load  ./data/temporal_test_stamp1_lag18_step48.npz
# --- test dataset ---
# x_test.shape = (1374, 10, 20, 18)
# y_test.shape = (1374, 10, 20, 48)
# temporal_test.shape = (1374, 48, 55)
# 43/43 [==============================] - 1s 8ms/step
# RMSE of Single-Step Forecast = 6.283
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 2-Step Forecast = 8.071
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 3-Step Forecast = 9.514
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 4-Step Forecast = 10.581
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 5-Step Forecast = 11.500
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 6-Step Forecast = 12.407
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 7-Step Forecast = 13.266
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 8-Step Forecast = 14.080
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 9-Step Forecast = 14.847
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 10-Step Forecast = 15.529
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 11-Step Forecast = 16.181
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 12-Step Forecast = 16.821
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 13-Step Forecast = 17.459
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 14-Step Forecast = 18.046
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 15-Step Forecast = 18.569
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 16-Step Forecast = 19.027
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 17-Step Forecast = 19.447
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 18-Step Forecast = 19.837
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 19-Step Forecast = 20.212
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 20-Step Forecast = 20.575
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 21-Step Forecast = 20.928
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 22-Step Forecast = 21.270
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 23-Step Forecast = 21.612
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 24-Step Forecast = 21.953
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 25-Step Forecast = 22.300
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 26-Step Forecast = 22.623
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 27-Step Forecast = 22.890
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 28-Step Forecast = 23.108
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 29-Step Forecast = 23.285
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 30-Step Forecast = 23.436
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 31-Step Forecast = 23.561
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 32-Step Forecast = 23.676
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 33-Step Forecast = 23.768
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 34-Step Forecast = 23.841
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 35-Step Forecast = 23.891
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 36-Step Forecast = 23.927
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 37-Step Forecast = 23.956
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 38-Step Forecast = 23.974
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 39-Step Forecast = 23.996
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 40-Step Forecast = 24.031
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 41-Step Forecast = 24.074
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 42-Step Forecast = 24.108
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 43-Step Forecast = 24.139
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 44-Step Forecast = 24.169
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 45-Step Forecast = 24.201
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 46-Step Forecast = 24.231
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 47-Step Forecast = 24.260
# (1374, 10, 20, 18)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 48-Step Forecast = 24.289
# Model Loaded: best_model_stamp1_lag20.h5
# [*] Success to load  ./data/x_train_stamp1_lag20.npz
# [*] Success to load  ./data/x_train_stamp1_lag20.npz
# [*] Success to load  ./data/x_test_stamp1_lag20_step48.npz
# [*] Success to load  ./data/y_test_stamp1_lag20_step48.npz
# [*] Success to load  ./data/temporal_test_stamp1_lag20_step48.npz
# --- test dataset ---
# x_test.shape = (1372, 10, 20, 20)
# y_test.shape = (1372, 10, 20, 48)
# temporal_test.shape = (1372, 48, 55)
# 43/43 [==============================] - 1s 9ms/step
# RMSE of Single-Step Forecast = 5.821
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 2-Step Forecast = 7.205
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 3-Step Forecast = 8.393
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 4-Step Forecast = 9.302
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 5-Step Forecast = 10.142
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 6-Step Forecast = 10.906
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 7-Step Forecast = 11.689
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 8-Step Forecast = 12.393
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 9-Step Forecast = 13.090
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 10-Step Forecast = 13.737
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 11-Step Forecast = 14.348
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 12-Step Forecast = 14.915
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 13-Step Forecast = 15.458
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 14-Step Forecast = 15.952
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 15-Step Forecast = 16.398
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 16-Step Forecast = 16.785
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 17-Step Forecast = 17.139
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 18-Step Forecast = 17.446
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 19-Step Forecast = 17.723
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 20-Step Forecast = 17.946
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 21-Step Forecast = 18.144
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 22-Step Forecast = 18.352
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 23-Step Forecast = 18.565
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 24-Step Forecast = 18.752
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 25-Step Forecast = 18.936
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 26-Step Forecast = 19.107
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 27-Step Forecast = 19.255
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 28-Step Forecast = 19.369
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 29-Step Forecast = 19.458
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 30-Step Forecast = 19.531
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 31-Step Forecast = 19.601
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 5ms/step
# RMSE of 32-Step Forecast = 19.664
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 33-Step Forecast = 19.719
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 34-Step Forecast = 19.769
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 35-Step Forecast = 19.816
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 36-Step Forecast = 19.860
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 37-Step Forecast = 19.895
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 38-Step Forecast = 19.929
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 39-Step Forecast = 19.963
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 40-Step Forecast = 20.002
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 41-Step Forecast = 20.054
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 42-Step Forecast = 20.125
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 43-Step Forecast = 20.198
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 44-Step Forecast = 20.270
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 45-Step Forecast = 20.350
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 46-Step Forecast = 20.452
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 47-Step Forecast = 20.575
# (1372, 10, 20, 20)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 48-Step Forecast = 20.714
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [16], in <cell line: 3>()
#       3 for i in range(len(time_unit)): # time unit에 따라
#       4     for j in range(len(lag_list)): # lag에 따라
#       5 #         train(STAMP=stamp_list[i], LAG=lag_list[j], STEP=step_list[i])
# ----> 6         table[i,j] = multi_step_forecast(STAMP=stamp_list[i], LAG=lag_list[j], STEP=step_list[i])
#       8 col_name = ['lag_'+str(i) for i in lag_list]
#       9 # index = np.arange(0, len(time_unit))
#
# Input In [13], in multi_step_forecast(STAMP, LAG, STEP)
#       1 def multi_step_forecast(STAMP, LAG, STEP):
#       2
#       3     # Load saved model
# ----> 4     model = tf.keras.models.load_model(f'./model_saved/best_model_stamp{STAMP}_lag{LAG}.h5')
#       5     print(f'Model Loaded: best_model_stamp{STAMP}_lag{LAG}.h5')
#       6     min_x, max_x = get_min_max(load_np_data(f'./data/x_train_stamp{STAMP}_lag{LAG}.npz'), 'min_max')
#
# File ~/miniconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~/miniconda3/lib/python3.8/site-packages/keras/saving/save.py:206, in load_model(filepath, custom_objects, compile, options)
#     204 if isinstance(filepath_str, str):
#     205   if not tf.io.gfile.exists(filepath_str):
# --> 206     raise IOError(f'No file or directory found at {filepath_str}')
#     208   if tf.io.gfile.isdir(filepath_str):
#     209     return saved_model_load.load(filepath_str, compile, options)
#
# OSError: No file or directory found at ./model_saved/best_model_stamp1_lag22.h5

# %%
col_name = ['lag_'+str(i) for i in lag_list]
# index = np.arange(0, len(time_unit))
index = [stamp_list, time_unit, step_list]
rmse_table = pd.DataFrame(table, columns=col_name, index=index)
# rmse_table.to_csv(f'rmse_table_recursive.csv')

# %%
rmse_table
# Out:
#                 lag_2      lag_4      lag_6     lag_8     lag_10     lag_12  \
# 1  0.5  48  22.339087  23.472982  24.185607  24.05702  24.277831  24.397066
# 2  1.0  24   0.000000   0.000000   0.000000   0.00000   0.000000   0.000000
# 4  2.0  12   0.000000   0.000000   0.000000   0.00000   0.000000   0.000000
# 6  3.0  8    0.000000   0.000000   0.000000   0.00000   0.000000   0.000000
# 8  4.0  6    0.000000   0.000000   0.000000   0.00000   0.000000   0.000000
# 12 6.0  4    0.000000   0.000000   0.000000   0.00000   0.000000   0.000000
# 16 8.0  3    0.000000   0.000000   0.000000   0.00000   0.000000   0.000000
# 24 12.0 2    0.000000   0.000000   0.000000   0.00000   0.000000   0.000000
# 48 24.0 1    0.000000   0.000000   0.000000   0.00000   0.000000   0.000000
#
#                lag_14     lag_16     lag_18     lag_20  lag_22  lag_24
# 1  0.5  48  24.404075  24.342032  24.289182  20.713554     0.0     0.0
# 2  1.0  24   0.000000   0.000000   0.000000   0.000000     0.0     0.0
# 4  2.0  12   0.000000   0.000000   0.000000   0.000000     0.0     0.0
# 6  3.0  8    0.000000   0.000000   0.000000   0.000000     0.0     0.0
# 8  4.0  6    0.000000   0.000000   0.000000   0.000000     0.0     0.0
# 12 6.0  4    0.000000   0.000000   0.000000   0.000000     0.0     0.0
# 16 8.0  3    0.000000   0.000000   0.000000   0.000000     0.0     0.0
# 24 12.0 2    0.000000   0.000000   0.000000   0.000000     0.0     0.0
# 48 24.0 1    0.000000   0.000000   0.000000   0.000000     0.0     0.0

# %%
stamp = 1; lag = 10 ; step = int(48/stamp)
multi_step_forecast(STAMP=stamp, LAG=lag, STEP=step)
# Out:
# Model Loaded: best_model_stamp1_lag10.h5
# [*] Success to load  ./data/x_train_stamp1_lag10.npz
# [*] Success to load  ./data/x_train_stamp1_lag10.npz
# [*] Success to load  ./data/x_test_stamp1_lag10_step48.npz
# [*] Success to load  ./data/y_test_stamp1_lag10_step48.npz
# [*] Success to load  ./data/temporal_test_stamp1_lag10_step48.npz
# --- test dataset ---
# x_test.shape = (1382, 10, 20, 10)
# y_test.shape = (1382, 10, 20, 48)
# temporal_test.shape = (1382, 48, 55)
# 2022-09-28 21:48:20.272624: E tensorflow/stream_executor/cuda/cuda_blas.cc:232] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2022-09-28 21:48:20.272683: E tensorflow/stream_executor/cuda/cuda_blas.cc:234] Failure to initialize cublas may be due to OOM (cublas needs some free memory when you initialize it, and your deep-learning framework may have preallocated more than its fair share), or may be because this binary was not built with support for the GPU in your machine.
# 2022-09-28 21:48:20.272714: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at matmul_op_impl.h:438 : INTERNAL: Attempting to perform BLAS operation using StreamExecutor without BLAS support
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Input In [13], in <cell line: 2>()
#       1 stamp = 1; lag = 10 ; step = int(48/stamp)
# ----> 2 multi_step_forecast(STAMP=stamp, LAG=lag, STEP=step)
#
# Input In [11], in multi_step_forecast(STAMP, LAG, STEP)
#      11 # Single-Step Forecast
#      12 temporal_test_step1 = temporal_test[:,0,:]
# ---> 13 y_pred =  model.predict([x_test, temporal_test_step1])
#      14 y_true = np.expand_dims(y_test[:,:,:,0], axis=-1)
#      16 y_pred_inv = scaler(y_pred, 'min_max', inv=True, min_value=min_x, max_value=max_x)
#
# File ~/miniconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# InternalError: Graph execution error:
#
# Detected at node 'model_1/dense_1/MatMul' defined at (most recent call last):
#     File "/home/jpark/miniconda3/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/home/jpark/miniconda3/lib/python3.8/runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/traitlets/config/application.py", line 976, in launch_instance
#       app.start()
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/home/jpark/miniconda3/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#       self._run_once()
#     File "/home/jpark/miniconda3/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#       handle._run()
#     File "/home/jpark/miniconda3/lib/python3.8/asyncio/events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#       res = shell.run_cell(
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2881, in run_cell
#       result = self._run_cell(
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2936, in _run_cell
#       return runner(coro)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3135, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3338, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3398, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_8168/2082855924.py", line 2, in <cell line: 2>
#       multi_step_forecast(STAMP=stamp, LAG=lag, STEP=step)
#     File "/tmp/ipykernel_8168/1422740731.py", line 13, in multi_step_forecast
#       y_pred =  model.predict([x_test, temporal_test_step1])
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/keras/engine/training.py", line 2033, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/keras/engine/training.py", line 1845, in predict_function
#       return step_function(self, iterator)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/keras/engine/training.py", line 1834, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/keras/engine/training.py", line 1823, in run_step
#       outputs = model.predict_step(data)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/keras/engine/training.py", line 1791, in predict_step
#       return self(x, training=False)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/keras/engine/training.py", line 490, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/keras/engine/base_layer.py", line 1014, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/keras/engine/functional.py", line 458, in call
#       return self._run_internal_graph(
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/keras/engine/functional.py", line 596, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/keras/engine/base_layer.py", line 1014, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/jpark/miniconda3/lib/python3.8/site-packages/keras/layers/core/dense.py", line 221, in call
#       outputs = tf.matmul(a=inputs, b=self.kernel)
# Node: 'model_1/dense_1/MatMul'
# Attempting to perform BLAS operation using StreamExecutor without BLAS support
# 	 [[{{node model_1/dense_1/MatMul}}]] [Op:__inference_predict_function_4323]

# %%
stamp = 2; lag = 10 ; step = int(48/stamp)

# train(STAMP=stamp, LAG=lag, STEP=step)

multi_step_forecast(STAMP=stamp, LAG=lag, STEP=step)
# Out:
# Model Loaded: best_model_stamp2_lag10.h5
# [*] Success to load  ./data/x_train_stamp2_lag10.npz
# [*] Success to load  ./data/x_train_stamp2_lag10.npz
# [*] Success to load  ./data/x_test_stamp2_lag10_step24.npz
# [*] Success to load  ./data/y_test_stamp2_lag10_step24.npz
# [*] Success to load  ./data/temporal_test_stamp2_lag10_step24.npz
# --- test dataset ---
# x_test.shape = (1396, 10, 20, 10)
# y_test.shape = (1396, 10, 20, 24)
# temporal_test.shape = (1396, 24, 55)
# 44/44 [==============================] - 1s 9ms/step
# RMSE of Single-Step Forecast = 7.043
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 2-Step Forecast = 8.552
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 3-Step Forecast = 9.777
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 4-Step Forecast = 11.016
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 5-Step Forecast = 12.199
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 6-Step Forecast = 13.246
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 7-Step Forecast = 14.132
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 8-Step Forecast = 14.840
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 9-Step Forecast = 15.442
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 10-Step Forecast = 16.012
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 11-Step Forecast = 16.486
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 12-Step Forecast = 16.944
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 13-Step Forecast = 17.382
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 14-Step Forecast = 17.822
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 15-Step Forecast = 18.220
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 16-Step Forecast = 18.605
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 17-Step Forecast = 18.980
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 18-Step Forecast = 19.352
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 19-Step Forecast = 19.716
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 20-Step Forecast = 20.098
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 21-Step Forecast = 20.456
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 22-Step Forecast = 20.811
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 23-Step Forecast = 21.137
# (1396, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 24-Step Forecast = 21.469
#          RMSE
# 0    7.043048
# 1    8.552234
# 2    9.777102
# 3   11.016491
# 4   12.198668
# 5   13.245946
# 6   14.131569
# 7   14.839915
# 8   15.442223
# 9   16.012144
# 10  16.486451
# 11  16.944259
# 12  17.381627
# 13  17.821776
# 14  18.219962
# 15  18.605362
# 16  18.979911
# 17  19.351846
# 18  19.715784
# 19  20.098237
# 20  20.455593
# 21  20.811175
# 22  21.137464
# 23  21.468527

# %%
stamp = 4; lag = 10 ; step = int(48/stamp)

# train(STAMP=stamp, LAG=lag, STEP=step)

multi_step_forecast(STAMP=stamp, LAG=lag, STEP=step)
# Out:
# Model Loaded: best_model_stamp4_lag10.h5
# [*] Success to load  ./data/x_train_stamp4_lag10.npz
# [*] Success to load  ./data/x_train_stamp4_lag10.npz
# [*] Success to load  ./data/x_test_stamp4_lag10_step12.npz
# [*] Success to load  ./data/y_test_stamp4_lag10_step12.npz
# [*] Success to load  ./data/temporal_test_stamp4_lag10_step12.npz
# --- test dataset ---
# x_test.shape = (1388, 10, 20, 10)
# y_test.shape = (1388, 10, 20, 12)
# temporal_test.shape = (1388, 12, 55)
# 44/44 [==============================] - 1s 8ms/step
# RMSE of Single-Step Forecast = 8.555
# (1388, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 2-Step Forecast = 10.802
# (1388, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 3-Step Forecast = 13.310
# (1388, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 4-Step Forecast = 15.545
# (1388, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 5-Step Forecast = 17.536
# (1388, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 6-Step Forecast = 19.372
# (1388, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 7-Step Forecast = 20.734
# (1388, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 8-Step Forecast = 21.526
# (1388, 10, 20, 10)
# 44/44 [==============================] - 0s 5ms/step
# RMSE of 9-Step Forecast = 21.507
# (1388, 10, 20, 10)
# 44/44 [==============================] - 0s 6ms/step
# RMSE of 10-Step Forecast = 20.664
# (1388, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 11-Step Forecast = 19.388
# (1388, 10, 20, 10)
# 44/44 [==============================] - 0s 7ms/step
# RMSE of 12-Step Forecast = 18.157
#          RMSE
# 0    8.554886
# 1   10.802294
# 2   13.309760
# 3   15.544580
# 4   17.536202
# 5   19.371976
# 6   20.734241
# 7   21.526197
# 8   21.506740
# 9   20.663516
# 10  19.387906
# 11  18.157104

# %%
stamp = 8; lag = 10 ; step = int(48/stamp)

# train(STAMP=stamp, LAG=lag, STEP=step)

multi_step_forecast(STAMP=stamp, LAG=lag, STEP=step)
# Out:
# Model Loaded: best_model_stamp8_lag10.h5
# [*] Success to load  ./data/x_train_stamp8_lag10.npz
# [*] Success to load  ./data/x_train_stamp8_lag10.npz
# [*] Success to load  ./data/x_test_stamp8_lag10_step6.npz
# [*] Success to load  ./data/y_test_stamp8_lag10_step6.npz
# [*] Success to load  ./data/temporal_test_stamp8_lag10_step6.npz
# --- test dataset ---
# x_test.shape = (1354, 10, 20, 10)
# y_test.shape = (1354, 10, 20, 6)
# temporal_test.shape = (1354, 6, 55)
# 43/43 [==============================] - 1s 8ms/step
# RMSE of Single-Step Forecast = 8.666
# (1354, 10, 20, 10)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 2-Step Forecast = 15.062
# (1354, 10, 20, 10)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 3-Step Forecast = 21.920
# (1354, 10, 20, 10)
# 43/43 [==============================] - 0s 7ms/step
# RMSE of 4-Step Forecast = 25.221
# (1354, 10, 20, 10)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 5-Step Forecast = 24.662
# (1354, 10, 20, 10)
# 43/43 [==============================] - 0s 6ms/step
# RMSE of 6-Step Forecast = 20.586
#         RMSE
# 0   8.665881
# 1  15.062003
# 2  21.919733
# 3  25.220655
# 4  24.661735
# 5  20.585779

# %%
stamp = 12; lag = 10 ; step = int(48/stamp)

# train(STAMP=stamp, LAG=lag, STEP=step)

multi_step_forecast(STAMP=stamp, LAG=lag, STEP=step)
# Out:
# Model Loaded: best_model_stamp12_lag10.h5
# [*] Success to load  ./data/x_train_stamp12_lag10.npz
# [*] Success to load  ./data/x_train_stamp12_lag10.npz
# [*] Success to load  ./data/x_test_stamp12_lag10_step4.npz
# [*] Success to load  ./data/y_test_stamp12_lag10_step4.npz
# [*] Success to load  ./data/temporal_test_stamp12_lag10_step4.npz
# --- test dataset ---
# x_test.shape = (1316, 10, 20, 10)
# y_test.shape = (1316, 10, 20, 4)
# temporal_test.shape = (1316, 4, 55)
# 42/42 [==============================] - 1s 8ms/step
# RMSE of Single-Step Forecast = 9.771
# (1316, 10, 20, 10)
# 42/42 [==============================] - 0s 6ms/step
# RMSE of 2-Step Forecast = 18.907
# (1316, 10, 20, 10)
# 42/42 [==============================] - 0s 7ms/step
# RMSE of 3-Step Forecast = 24.710
# (1316, 10, 20, 10)
# 42/42 [==============================] - 0s 6ms/step
# RMSE of 4-Step Forecast = 21.791
#         RMSE
# 0   9.770522
# 1  18.906719
# 2  24.709987
# 3  21.790642

# %%
stamp = 24; lag = 10 ; step = int(48/stamp)

# train(STAMP=stamp, LAG=lag, STEP=step)

multi_step_forecast(STAMP=stamp, LAG=lag, STEP=step)
# Out:
# Model Loaded: best_model_stamp24_lag10.h5
# [*] Success to load  ./data/x_train_stamp24_lag10.npz
# [*] Success to load  ./data/x_train_stamp24_lag10.npz
# [*] Success to load  ./data/x_test_stamp24_lag10_step2.npz
# [*] Success to load  ./data/y_test_stamp24_lag10_step2.npz
# [*] Success to load  ./data/temporal_test_stamp24_lag10_step2.npz
# --- test dataset ---
# x_test.shape = (1198, 10, 20, 10)
# y_test.shape = (1198, 10, 20, 2)
# temporal_test.shape = (1198, 2, 55)
# 38/38 [==============================] - 1s 9ms/step
# RMSE of Single-Step Forecast = 9.800
# (1198, 10, 20, 10)
# 38/38 [==============================] - 0s 6ms/step
# RMSE of 2-Step Forecast = 25.367
#         RMSE
# 0   9.800317
# 1  25.367216
